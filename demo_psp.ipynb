# %%
# %matplotlib inline

# %% [markdown]
# 2. Test with PSPNet Pre-trained Models
# ======================================
#
# This is a quick demo of using GluonCV PSPNet model on ADE20K dataset.
# Please follow the `installation guide <../index.html>`_ to install MXNet and GluonCV if not yet.

# %%
import mxnet as mx
from mxnet import image
from mxnet.gluon.data.vision import transforms
import gluoncv
# using cpu
ctx = mx.cpu(0)

# %% [markdown]
# Prepare the image
# -----------------
#
# download the example image

# %%
# url = 'https://github.com/zhanghang1989/image-data/blob/master/encoding/' + \
#     'segmentation/ade20k/ADE_val_00001142.jpg?raw=true'
# filename = 'ade20k_example.jpg'
filename = r'I:\StreetViewImage\Morris2_pano\__QDvI3gVjauKchKZNBr1Q_-74.3453977_40.8973662.jpg'
#gluoncv.utils.download(url, filename, True)

# %% [markdown]
# load the image

# %%
img = image.imread(filename)

from matplotlib import pyplot as plt
plt.imshow(img.asnumpy())
plt.show()

# %% [markdown]
# normalize the image using dataset mean

# %%
from gluoncv.data.transforms.presets.segmentation import test_transform
img = test_transform(img, ctx)

# %% [markdown]
# Load the pre-trained model and make prediction
# ----------------------------------------------
#
# get pre-trained model

# %%
model = gluoncv.model_zoo.get_model('psp_resnet101_ade', pretrained=True)
# Out:
# self.crop_size 480

# %% [markdown]
# make prediction using single scale

# %%
output = model.predict(img)
predict = mx.nd.squeeze(mx.nd.argmax(output, 1)).asnumpy()
# Out:
# ---------------------------------------------------------------------------
# MXNetError                                Traceback (most recent call last)
# <ipython-input-19-9450a7f7a970> in <module>
#       1 output = model.predict(img)
# ----> 2 predict = mx.nd.squeeze(mx.nd.argmax(output, 1)).asnumpy()
#
# d:\Anaconda3\lib\site-packages\mxnet\ndarray\ndarray.py in asnumpy(self)
#    1994             self.handle,
#    1995             data.ctypes.data_as(ctypes.c_void_p),
# -> 1996             ctypes.c_size_t(data.size)))
#    1997         return data
#    1998
#
# d:\Anaconda3\lib\site-packages\mxnet\base.py in check_call(ret)
#     251     """
#     252     if ret != 0:
# --> 253         raise MXNetError(py_str(_LIB.MXGetLastError()))
#     254
#     255
#
# MXNetError: [21:10:18] c:\jenkins\workspace\mxnet-tag\mxnet\src\storage\./cpu_device_storage.h:72: Failed to allocate CPU Memory

# %% [markdown]
# Add color pallete for visualization

# %%
from gluoncv.utils.viz import get_color_pallete
import matplotlib.image as mpimg
mask = get_color_pallete(predict, 'ade20k')
mask.save('output.png')

# %% [markdown]
# show the predicted mask

# %%
mmask = mpimg.imread('output.png')
plt.imshow(mmask)
plt.show()
