# %%
folder = r'K:\Research\Trees\NewYorkCity_test\tree_detected\*.txt'

# %%
import glob

files = glob.glob(folder)
files
# Out:
# ['K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\--021533nDTBmWNlSasfIQ_-74.236415_40.505897_0_345.62.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\--F_i3rpgGBpAPhGHaLXZQ_-74.242277_40.504715_0_165.34.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\--t82459ApuOEgTto8Q_cw_-74.201657_40.552125_0_252.70.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-0Ckl3NMswcH13mGLPJ1wg_-74.202244_40.555939_0_186.12.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-0Ckl3NMswcH13mGLPJ1wg_-74.202244_40.555939_0_6.12.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-0cRQ4FINinjbqJH9gGRNQ_-74.211307_40.549958_0_315.53.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-0duyXgY2xbxroopuiu-vg_-74.205296_40.528848_0_169.00.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-0fcCEixIfEAHhUQcwF78Q_-74.204802_40.533541_0_163.43.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-0fcCEixIfEAHhUQcwF78Q_-74.204802_40.533541_0_343.43.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-0FtZYwL-qyzAY18M-XhRw_-74.244531_40.507619_0_253.47.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-0FtZYwL-qyzAY18M-XhRw_-74.244531_40.507619_0_73.47.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-0jcQnzmewetv7ACQJE-tA_-74.197556_40.55521_0_122.98.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-0jcQnzmewetv7ACQJE-tA_-74.197556_40.55521_0_302.98.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-0Qx5lOp6HLMApAxyP6qiQ_-74.200208_40.519258_0_344.25.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-0Xqxc3UMTLCdtBOc9Abzg_-74.22117_40.54918_0_345.20.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-0yk0f0sCdYY4BVpiuOkFQ_-74.217694_40.543128_0_164.96.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-0yk0f0sCdYY4BVpiuOkFQ_-74.217694_40.543128_0_344.96.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-1fkpnXin9Lc-oJQDwjLiQ_-74.214849_40.525544_0_175.57.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-1Ncts3UhVmGbTgKnBCkNg_-74.250129_40.507627_0_250.44.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-2q9rd03GjkpcUJDuNX-lw_-74.202488_40.54301_0_249.64.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-35DvCgHTsrVAQWhlpcZtQ_-74.200487_40.539297_0_158.71.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-35DvCgHTsrVAQWhlpcZtQ_-74.200487_40.539297_0_338.71.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-4dmYAuKAnABJ2tj_SDpWA_-74.203489_40.53999_0_155.96.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-4dmYAuKAnABJ2tj_SDpWA_-74.203489_40.53999_0_335.96.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-5qQ6Klj4hDru0anty7P8w_-74.210622_40.548376_0_255.33.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-5qQ6Klj4hDru0anty7P8w_-74.210622_40.548376_0_75.33.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-5TSxOUb1vdQIATaEWe2Mw_-74.21182_40.536684_0_265.01.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-5UT_PSP6F6E5Sh2Vrqzng_-74.240726_40.505031_0_345.81.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-60oB49uxTDHRU7DuOWAow_-74.249148_40.501606_0_255.29.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-60oB49uxTDHRU7DuOWAow_-74.249148_40.501606_0_75.29.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-7ay3sBaEXf2CHrzlkF4gw_-74.203651_40.54257_0_253.91.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-7ay3sBaEXf2CHrzlkF4gw_-74.203651_40.54257_0_73.91.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-7CcRMCdIPqNUUMWo9dC8A_-74.243978_40.509079_0_347.22.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-855ph9xSl1UlnwGPJYSlg_-74.251664_40.50657_0_79.34.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-8a1Kq_MiURpfGrBSUJGJA_-74.199583_40.533826_0_320.29.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-9a-fG4CIieAj_6wr_9k-w_-74.249263_40.513174_0_52.98.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-9ayIznJvN_-vmaaYLSU4w_-74.202974_40.534036_0_160.63.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-9ayIznJvN_-vmaaYLSU4w_-74.202974_40.534036_0_340.63.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-9bVoe0T0w4yL87QEqCVeg_-74.216642_40.545594_0_164.68.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-9fFf3RU3jrVLwgHX3b1sw_-74.202197_40.541888_0_158.02.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-9sN63_H3hnbNLN29fuulA_-74.198793_40.520275_0_164.19.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-9sN63_H3hnbNLN29fuulA_-74.198793_40.520275_0_344.19.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-9UsL8R2IeddvNcLIe2riQ_-74.203939_40.534523_0_163.65.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-a5ApBRQHzMG3FzHLTHtbA_-74.197896_40.547847_0_157.67.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-a5ApBRQHzMG3FzHLTHtbA_-74.197896_40.547847_0_337.67.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-aldfl9jq0i7L70gRG89UA_-74.215395_40.552814_0_137.46.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-B0rKWA5on2qHZlpTJt14A_-74.243258_40.50865_0_255.36.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-b10uO3kc3SUCFcV4koVsQ_-74.207212_40.527077_0_174.92.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-b10uO3kc3SUCFcV4koVsQ_-74.207212_40.527077_0_354.92.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-BD-fnMrjpltb066L5g-zw_-74.208512_40.544501_0_163.32.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-BD-fnMrjpltb066L5g-zw_-74.208512_40.544501_0_343.32.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-BLi6mRPhj6teRftIVBsrw_-74.216954_40.528921_0_254.74.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-bMthe5CfHPDCG0B2CIZBg_-74.197254_40.51984_0_260.52.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-bMthe5CfHPDCG0B2CIZBg_-74.197254_40.51984_0_80.52.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-BOtHMAckZGIhCTMzyyoMA_-74.21739_40.530202_0_256.86.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-bpMT6vekFAyyFnljTWILQ_-74.204792_40.529796_0_250.24.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-bQxe8613cQU_a06mhImSg_-74.196649_40.515965_0_170.46.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-C46MsRsqQlEMwQJzROPHQ_-74.21618_40.553565_0_318.35.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-c9Ff4hMTJerqzmTEAlKpg_-74.212486_40.517498_0_256.68.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-cFfsNtwoAykgZS6Ujtl_g_-74.254305_40.50635_0_255.75.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-cFfsNtwoAykgZS6Ujtl_g_-74.254305_40.50635_0_75.75.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-cHOuqC7qEkY74tea6O0BQ_-74.209789_40.551557_0_165.20.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-cHOuqC7qEkY74tea6O0BQ_-74.209789_40.551557_0_345.20.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-cqYY1i-sIog8OwStgEn2g_-74.204756_40.542033_0_351.70.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-d1Uzrpzwca_sWyNtOD1dA_-74.241155_40.513452_0_234.07.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-d1Uzrpzwca_sWyNtOD1dA_-74.241155_40.513452_0_54.07.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-DbIyQbqsTscH-SoTrGA0g_-74.202034_40.555221_0_251.69.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-DbIyQbqsTscH-SoTrGA0g_-74.202034_40.555221_0_71.69.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-DVH_bu0YC5wGz9oQmqdTg_-74.195893_40.534891_0_19.40.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-e35jGyDcPs6wJSxw4NIRA_-74.199674_40.54905_0_93.67.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-e8APhLW7n-ep_cSMLWmIA_-74.201344_40.526011_0_245.11.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-eHoeUtq20aLyrCRwOrj8g_-74.195457_40.530236_0_327.96.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-eI3jDfZKWy83u45RERaNg_-74.239432_40.521403_0_101.10.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-EID0iGE7ANjagGxQOX9pA_-74.251786_40.507616_0_161.91.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-EID0iGE7ANjagGxQOX9pA_-74.251786_40.507616_0_341.91.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-EMv7UAPfe4R3YThfIf5IA_-74.250923_40.511643_0_54.94.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-EUmSkgU1CF8qNAma5EP8A_-74.207588_40.519593_0_162.19.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-f3NnV-FJ8L8Szwpf2-SfA_-74.24262_40.510503_0_143.07.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-FH-wojjaqEdRnEjPN2KZg_-74.199549_40.551821_0_344.58.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-FlVMBJ9TrvwxiSSxx_8Dg_-74.218539_40.529319_0_11.56.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-FlVMBJ9TrvwxiSSxx_8Dg_-74.218539_40.529319_0_191.56.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-FsULQUa_k1iGTdHKprxNQ_-74.209226_40.52013_0_255.40.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-FsULQUa_k1iGTdHKprxNQ_-74.209226_40.52013_0_75.40.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-FUgF9kyzEnz35hT3IAVsQ_-74.234783_40.523606_0_176.82.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-FuTlLpYfa0W65iKhx9b7g_-74.202026_40.532782_0_339.63.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-G8cnyimDsFZ17OHD4d56g_-74.245796_40.503093_0_251.39.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-gKWrHCTyWok9T7cQRzhXg_-74.222069_40.523553_0_176.16.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-Gyfvf4TXA4YslRtwDe4hw_-74.241261_40.502252_0_165.72.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-Gyfvf4TXA4YslRtwDe4hw_-74.241261_40.502252_0_345.72.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-g_v3EsarNfq8xgOh2lwUg_-74.215806_40.548085_0_344.29.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-h4W0i8y2URGsGIUWEphHg_-74.236889_40.510544_0_169.46.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-HfVic1ee0YdWdyhIYLvSA_-74.197568_40.558788_0_50.10.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-HJXGj8KEz3oS4YrUwXOzg_-74.216505_40.537956_0_192.26.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-hn3fhlkAOw8Sc5GjrDSVg_-74.250383_40.507283_0_158.99.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-ICmsZPPTKJbmvJvIxqk2Q_-74.252893_40.504311_0_241.55.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-IgFWpNf4sR_liDUMjUtSA_-74.203937_40.528419_0_173.05.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-inSXp0dWFRsiQ2nY0fW6Q_-74.203512_40.538439_0_160.69.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-IpvguCFoFm22OPL9oP8jg_-74.199468_40.555293_0_308.76.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-iSrsVLKDC4yAKlrpCEBrQ_-74.211621_40.545829_0_253.69.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-iSrsVLKDC4yAKlrpCEBrQ_-74.211621_40.545829_0_73.69.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-J1zdAbAm2bt4XAe6IXo0g_-74.203909_40.535295_0_339.75.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-J4I4ZDM7MCe0z-KZYMTwA_-74.204623_40.529452_0_251.48.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-J4I4ZDM7MCe0z-KZYMTwA_-74.204623_40.529452_0_71.48.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-J5UEEsJXewUYgGnvj6ZhQ_-74.25123_40.507035_0_340.68.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-jLo3OvHtFGhj2gxPNC9OA_-74.24377_40.502661_0_255.34.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-jLo3OvHtFGhj2gxPNC9OA_-74.24377_40.502661_0_75.34.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-jm3Mr9hBsaaN7aOtymPug_-74.21048_40.544151_0_172.84.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-JmWZk4uOKobAHOJEsGakA_-74.2449_40.509369_0_76.48.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-JtL6zhkEfTTexgyW9jkbg_-74.203848_40.523729_0_50.31.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-jyWM3GBBeqi7EL99CdK5A_-74.252504_40.511782_0_231.77.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-JZEwwCDWAHVnNxddva-_A_-74.21224_40.516714_0_257.79.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-kEncxTEyCijb6Lw9ml-Zg_-74.241445_40.514336_0_133.32.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-kEncxTEyCijb6Lw9ml-Zg_-74.241445_40.514336_0_313.32.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-kFoKr-Uu5VTSKhznlbG7g_-74.222334_40.53206_0_11.91.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-kFoKr-Uu5VTSKhznlbG7g_-74.222334_40.53206_0_191.91.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-kR6-GNKEHnGIi_kfnLneQ_-74.197859_40.546268_0_68.80.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-kUkXrJWpMqkkQ2Oy5OhJg_-74.199534_40.526708_0_315.14.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-lBJ9GSsUq3JhMAvhJGpiA_-74.2438_40.500041_0_255.38.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-lBJ9GSsUq3JhMAvhJGpiA_-74.2438_40.500041_0_75.38.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-Ld6-GiX_gUgPH6YfXqYfQ_-74.211563_40.534334_0_265.42.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-LKh8KT31ln-pXfWcYAblA_-74.211969_40.543431_0_265.62.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-LKh8KT31ln-pXfWcYAblA_-74.211969_40.543431_0_85.62.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-LMyFeckbw8fPQlQGsnIAA_-74.195595_40.515857_0_259.55.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-LMyFeckbw8fPQlQGsnIAA_-74.195595_40.515857_0_79.55.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-loW9oprT0QdpP_daiiXYg_-74.202932_40.516607_0_320.90.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-Lrir75zaea5U14mYd6g4A_-74.243556_40.502028_0_256.54.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-Lrir75zaea5U14mYd6g4A_-74.243556_40.502028_0_76.54.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-Lv8w_kOYXgXzwU36XHegw_-74.223786_40.507347_0_91.24.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-MGoHkzUSvdQlH44cmEg7g_-74.213379_40.541357_0_182.39.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-MKyCaPjntXFbPZsXPRhpA_-74.238205_40.517085_0_144.89.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-MKyCaPjntXFbPZsXPRhpA_-74.238205_40.517085_0_324.89.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-mmrr4nHgf3YvD2K89L93g_-74.202916_40.538125_0_73.94.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-n1E14wtMmX6Sj1NpnPJqw_-74.25319_40.505679_0_93.83.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-N7j_lHkt9d8Hphqg8VnNQ_-74.197952_40.54908_0_73.58.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-n7UDZ9_EoHhflgtCyieig_-74.204401_40.517165_0_246.50.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-nB6cxCFuwpGaWi4IkyuVA_-74.233682_40.516902_0_221.39.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-nD2qvwq1FpD1kocPBsAJg_-74.212632_40.540453_0_7.54.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-Ne2ip49hg_W8lcS3glyHg_-74.250568_40.51289_0_53.35.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-NROCJ4ESZ4ybUVI2qkb9g_-74.251771_40.511062_0_239.86.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-NROCJ4ESZ4ybUVI2qkb9g_-74.251771_40.511062_0_59.86.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-nVd3dgjWfVwU-MjVf7HfA_-74.20807_40.544602_0_128.69.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-nwbpfxX6ZLp6SB0rX3Ktw_-74.214223_40.528564_0_162.00.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-o0pXjEj1pqH3JiFfek-nA_-74.215415_40.552636_0_159.83.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-O1GM5sYib1JcoSjLcSuDw_-74.240305_40.516427_0_233.75.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-ofh_XvmWKlLR5lZLWEWow_-74.203106_40.537045_0_341.19.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-og9ogcR79VMfQLHnPLvtw_-74.237765_40.500636_0_228.97.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-os-NpUlnFdGDJ3ZYeXTAA_-74.212512_40.553252_0_290.66.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-P5poNhg63jG6rj33HjnyQ_-74.198998_40.527119_0_159.69.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-pdQ2B24WGhaS3ip3B51ew_-74.248939_40.510243_0_150.91.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-pdQ2B24WGhaS3ip3B51ew_-74.248939_40.510243_0_330.91.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-PDx5o-_Rh4DxTOppLyOGA_-74.2202_40.523662_0_173.79.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-PDx5o-_Rh4DxTOppLyOGA_-74.2202_40.523662_0_353.79.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-PH87pd0GhENtI2IG9tXDg_-74.209657_40.549032_0_165.31.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-PH87pd0GhENtI2IG9tXDg_-74.209657_40.549032_0_345.31.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-phJvwx7FZbmME9N5Frggw_-74.239184_40.531172_0_275.02.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-phJvwx7FZbmME9N5Frggw_-74.239184_40.531172_0_95.02.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-pNMwPwJWIMu7GYXdEPWUA_-74.210736_40.546069_0_253.35.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-pNMwPwJWIMu7GYXdEPWUA_-74.210736_40.546069_0_73.35.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-PqAvOj8HApYINOy5v_w0g_-74.214787_40.549795_0_342.13.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-pqnOyAaebPO_DNJDg3nKg_-74.217029_40.543277_0_164.57.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-pqnOyAaebPO_DNJDg3nKg_-74.217029_40.543277_0_344.57.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-Pt3dniradAEdjzbx6j3MQ_-74.20424_40.536725_0_160.07.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-pVV47_QP6q6x5LEIfJH6A_-74.215579_40.524665_0_92.07.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-q-tThSACxLp0FtmJgDuyw_-74.202694_40.536391_0_179.23.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-q693tReRIkXvWwNs196Rg_-74.245078_40.504158_0_165.11.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-QjIzL7KIkZQEhVPW8nceQ_-74.199037_40.546423_0_249.53.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-qPOh7DHPAQS2o3aYzhivA_-74.206482_40.534579_0_159.55.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-QQOM8H_XnT1_nGCVvwWUQ_-74.210085_40.552395_0_345.29.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-qxd3be5gwXHxIHgD3OZkw_-74.244708_40.5054_0_255.92.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-qxd3be5gwXHxIHgD3OZkw_-74.244708_40.5054_0_75.92.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-qZmA2ZL3JQG1y_pdJnzeQ_-74.248387_40.500836_0_345.87.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-R3iDqXNuDcL1HOsVH6uCg_-74.243341_40.501402_0_259.07.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-R3iDqXNuDcL1HOsVH6uCg_-74.243341_40.501402_0_79.07.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-rcK66gua23shxi59lrFGg_-74.210541_40.538972_0_172.57.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-rcK66gua23shxi59lrFGg_-74.210541_40.538972_0_352.57.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-RhPaJuNrYfBdJlp6w5Xuw_-74.239654_40.534374_0_279.13.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-RhPaJuNrYfBdJlp6w5Xuw_-74.239654_40.534374_0_99.13.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-rLA-oCMPvIrZWKthhgIdg_-74.214209_40.550693_0_69.01.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-rndwKQgYc6bCApJXGOVyg_-74.204978_40.528945_0_161.97.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-rndwKQgYc6bCApJXGOVyg_-74.204978_40.528945_0_341.97.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-rtMzCoxPt4qUixEUfLCcg_-74.211586_40.545743_0_253.60.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-rtMzCoxPt4qUixEUfLCcg_-74.211586_40.545743_0_73.60.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-rxpzEEPQBCvn-0xi4HN7Q_-74.239468_40.535874_0_279.39.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-rykyueEb4kEITvkgTJL6Q_-74.198076_40.520421_0_164.20.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-sDptMtvmmdWM83fgOJV1g_-74.212536_40.524265_0_349.84.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-sicpgodRS1YwPgF3G8oig_-74.219511_40.531655_0_190.52.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-SOgn8ghKtLtdOvbFotwRw_-74.227296_40.52779_0_323.05.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-sYAEnxG8bml6QpSVKr3Ag_-74.240522_40.504422_0_255.44.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-sYAEnxG8bml6QpSVKr3Ag_-74.240522_40.504422_0_75.44.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-Tbz1VPHTMEYENtI74BA9g_-74.227164_40.528005_0_316.16.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-tjBJE1pflbwx6lYmdESlw_-74.219561_40.522935_0_176.47.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-T_NnLmU3fEdOWgYLBl67g_-74.199362_40.526839_0_316.89.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-UTt_tBRITppfBdImYfplw_-74.199558_40.537274_0_157.96.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-Utun8P59-H8L0DhUwaP8w_-74.229669_40.507825_0_347.29.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-vBZLYnQ2RlGo6em0BlY6w_-74.224648_40.510724_0_251.71.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-vBZLYnQ2RlGo6em0BlY6w_-74.224648_40.510724_0_71.71.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-VIwNoZPebhyOGgpzNTVUw_-74.212229_40.519746_0_168.84.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-VJFxX9NqKZtoqMByJ7U-A_-74.198346_40.518861_0_164.45.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-vkFilQr-nEcmjWwVQMsQQ_-74.214986_40.543665_0_172.49.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-vm-nsCEqCripZZzg0a6QQ_-74.234997_40.52167_0_161.85.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-w7s18HM_bwQhZZMpsdT1Q_-74.238542_40.516967_0_258.84.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-WbI1HRFZx5PBv83BVHT7g_-74.222175_40.531978_0_295.31.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-wkZToX9ia-WbEu9nel8gg_-74.226579_40.528698_0_296.90.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-Wsf8cKAwCS52zjdOKLxHA_-74.210006_40.54673_0_257.77.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-wULBExb_iZv9Be2CHnXhw_-74.206017_40.532423_0_337.59.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-xcdCaLMM4Sp1rhoeT5BZw_-74.240452_40.505087_0_162.90.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-YBvA5w3qjF4ufrhPsNgLg_-74.251548_40.506076_0_79.42.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-YCsJw4YBSCP5wnMxt6kTQ_-74.209141_40.550697_0_252.65.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-YErKsUikGLIOAsZJRXvMQ_-74.213189_40.521608_0_172.49.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-Yg-95vqRu7EC7R2PQ7Rbw_-74.230074_40.528834_0_274.36.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-yLVBQ37UeuamtSnnlMpOQ_-74.237841_40.521195_0_184.77.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-ytrIc6xxyojtZnIZt1F1w_-74.19863_40.541553_0_245.99.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-ytrIc6xxyojtZnIZt1F1w_-74.19863_40.541553_0_65.99.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-z6TMzQsuhiCtvyCxt6EaQ_-74.203354_40.539312_0_215.32.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-z6TMzQsuhiCtvyCxt6EaQ_-74.203354_40.539312_0_35.32.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-zJKo_yC7kQLBZwt1r3xTQ_-74.239985_40.509563_0_158.57.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-zJKo_yC7kQLBZwt1r3xTQ_-74.239985_40.509563_0_338.57.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-ZjPJiXnuSJ5rdpebhCY5A_-74.213282_40.543131_0_169.99.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-ZjPJiXnuSJ5rdpebhCY5A_-74.213282_40.543131_0_349.99.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-zlBn6BeGHbYyzi5hBytXw_-74.244277_40.501442_0_258.27.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-zlBn6BeGHbYyzi5hBytXw_-74.244277_40.501442_0_78.27.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-Zm3Tl5iXNHhII9kkgixIw_-74.202345_40.553857_0_71.22.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-_j1vs6CKKy14q1zS755Fw_-74.218898_40.545861_0_163.50.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-_j1vs6CKKy14q1zS755Fw_-74.218898_40.545861_0_343.50.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-_QeRel6DdUP0qYEoRfN_g_-74.198032_40.546592_0_70.34.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\-_T3_ILK27anBoa0nP2SzQ_-74.205274_40.529608_0_159.22.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0-fqjN_VURtHVOxKnb7I4A_-74.206619_40.540094_0_257.25.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0-vjmwZZUkTv55fKdJwIUg_-74.234977_40.522437_0_274.37.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\001YeCEmnQ7mQDxRTF-_cg_-74.218645_40.548932_0_165.58.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\001YeCEmnQ7mQDxRTF-_cg_-74.218645_40.548932_0_345.58.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\00AI3gFTXeKCO9L7XgYLRg_-74.21377_40.5423_0_172.16.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\00AI3gFTXeKCO9L7XgYLRg_-74.21377_40.5423_0_352.16.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\00QCVukNKPBmHRawYiNQag_-74.243678_40.505122_0_255.37.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\00QCVukNKPBmHRawYiNQag_-74.243678_40.505122_0_75.37.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\017Z5DBeTH_GKleNzBXSzA_-74.202438_40.513204_0_346.45.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\01JsKN4y9JlIIwEsyiNiRQ_-74.223776_40.508142_0_270.89.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\01JsKN4y9JlIIwEsyiNiRQ_-74.223776_40.508142_0_90.89.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\01O5THZKGogQHEY8Qz2HvQ_-74.238665_40.517595_0_167.53.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\01Vz4R3WvdhPOKzki2d9iQ_-74.206519_40.522943_0_268.30.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\01Vz4R3WvdhPOKzki2d9iQ_-74.206519_40.522943_0_88.30.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\02lFYtDn3jEOlYdAHiYfJw_-74.239592_40.498907_0_264.84.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\033X_sXoKavGoX-yUAE4cQ_-74.202831_40.531325_0_263.94.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\03F4RJwB72GHmBg6D6fjrQ_-74.235539_40.514025_0_74.39.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\048AkHtPvFdCYAQ2kSZs7A_-74.213421_40.521571_0_165.77.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\04kvb3ib2LTQYTjVSTmBKw_-74.200619_40.519178_0_166.21.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\04kvb3ib2LTQYTjVSTmBKw_-74.200619_40.519178_0_346.21.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\055U94ryH4oEwCl-Xb4jCg_-74.195994_40.544303_0_319.46.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\05b0jUhUkQc9ix-W1UiwcA_-74.210869_40.55222_0_163.99.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\05b0jUhUkQc9ix-W1UiwcA_-74.210869_40.55222_0_343.99.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\05QxqxXXNBg4S-hyR2LAUA_-74.238993_40.536701_0_13.10.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\05wL99m0HSB8RTJit-iZRA_-74.234845_40.527065_0_272.30.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\05Yg3DQd11y-gW7vayb40Q_-74.201198_40.534528_0_341.34.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\065ZBqwXRNmBwi97xLUgHg_-74.247146_40.510913_0_156.32.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\065ZBqwXRNmBwi97xLUgHg_-74.247146_40.510913_0_336.32.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\06HqqrOwvILTV0UBcFPQlg_-74.21123_40.549919_0_73.07.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\071LaISU8lrn5qTUkALvcg_-74.230545_40.527653_0_185.47.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\071LaISU8lrn5qTUkALvcg_-74.230545_40.527653_0_5.47.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\074GwZZbvjex4y-YnyRIDg_-74.235702_40.510463_0_343.32.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\07spSy_yYQuFHRVB2R6OJQ_-74.242826_40.499915_0_255.90.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\07spSy_yYQuFHRVB2R6OJQ_-74.242826_40.499915_0_75.90.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\07SZY5E9WVLY6SoV-kbaNA_-74.239819_40.51341_0_53.99.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\07wus5eGN_90q0-AAmxiWg_-74.196139_40.531279_0_161.93.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\07wus5eGN_90q0-AAmxiWg_-74.196139_40.531279_0_341.93.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\081Cg_r4VklWd1axeV1VQA_-74.23947_40.516396_0_322.59.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\08lL-ehKZXS_soccOyJ-hg_-74.20378_40.536855_0_159.70.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\08lL-ehKZXS_soccOyJ-hg_-74.20378_40.536855_0_339.70.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\096E-Q7neREX8EjfA3KyIw_-74.228977_40.507963_0_347.29.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\09DmxnAq4-baIfthX3xt-w_-74.243633_40.502256_0_256.28.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\09DmxnAq4-baIfthX3xt-w_-74.243633_40.502256_0_76.28.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\09odbu2ipCgFL8NwfBYbBQ_-74.238967_40.507864_0_73.84.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\09q1y-_qhF1dg6HunrhpyQ_-74.249262_40.507812_0_69.78.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\09WTvwYOj3ev2M919rv2hg_-74.197598_40.556505_0_324.03.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0ahIcXB1_5tSrkhe2EyMrA_-74.216396_40.527738_0_68.79.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0aSVF4XyYpigE6_1eoKbwQ_-74.215597_40.542817_0_165.79.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0aSVF4XyYpigE6_1eoKbwQ_-74.215597_40.542817_0_345.79.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0aUWtAbkeqkpiqEjmy-cqQ_-74.218154_40.523799_0_176.69.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0aUWtAbkeqkpiqEjmy-cqQ_-74.218154_40.523799_0_356.69.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0aZv6J2TsY_2Geesv-bmsg_-74.204596_40.517504_0_246.86.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0aZv6J2TsY_2Geesv-bmsg_-74.204596_40.517504_0_66.86.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0BafuBo9OVLeUBSaxSol2g_-74.240878_40.517547_0_142.22.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0BJpimt7uaCpjAmN-vHwjw_-74.217812_40.549565_0_252.71.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0BJpimt7uaCpjAmN-vHwjw_-74.217812_40.549565_0_72.71.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0bK9gFJt4l5l815215Pnkg_-74.204133_40.518638_0_252.41.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0bv6Rl4s2I_EfiDpSNEcKQ_-74.196192_40.553793_0_143.13.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0C8cvd1do3Gul-MhndV6KA_-74.206503_40.538379_0_159.29.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0C8cvd1do3Gul-MhndV6KA_-74.206503_40.538379_0_339.29.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0Cb4nn7osGkWZwrjogoxgg_-74.19526_40.54226_0_340.54.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0CQR5qTP1KPkurutFmOqXQ_-74.198946_40.546477_0_70.19.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0d5SD3ld6TKhzOWsFjKrHg_-74.195885_40.518057_0_157.42.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0De0jOej13aFVFr8wKLEMw_-74.201886_40.526154_0_335.56.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0DQ7asPwnH_BY9k9oQ8Kfg_-74.198334_40.527649_0_131.66.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0DtMyGZGL9vTYsIzjCJVhA_-74.239393_40.509006_0_75.32.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0DVVrlAviJuuquMWPWHFsg_-74.200769_40.550839_0_163.18.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0DVVrlAviJuuquMWPWHFsg_-74.200769_40.550839_0_343.18.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0DZkS2m_yrl3UtMuiilrfg_-74.211695_40.535542_0_85.59.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0D_sTvvxS24kHh5JHldlWQ_-74.208724_40.537587_0_257.63.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0D_sTvvxS24kHh5JHldlWQ_-74.208724_40.537587_0_77.63.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0EOHmEDiK9hCf-C3Clf3SA_-74.209538_40.523007_0_99.29.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0Euq6cq66DAddg_lvBpc5w_-74.20229_40.533474_0_339.14.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0E_M8-F6Uv5xYB-KQlJAxQ_-74.245099_40.50109_0_73.77.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0fci0DiOtCuoGueSlpPNxA_-74.238429_40.515705_0_234.15.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0fci0DiOtCuoGueSlpPNxA_-74.238429_40.515705_0_54.15.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0Fl-GSPilzI0sEYRSJDrTw_-74.236999_40.514194_0_234.40.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0Fl-GSPilzI0sEYRSJDrTw_-74.236999_40.514194_0_54.40.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0flGH5arOxKLRbw5ccaA3A_-74.214985_40.524038_0_353.60.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0fmHn1oVapwcotPZFVYY1Q_-74.196591_40.555409_0_102.27.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0fmHn1oVapwcotPZFVYY1Q_-74.196591_40.555409_0_282.27.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0F_vqCLnq2ysivJ1dlXzyQ_-74.215789_40.545049_0_171.49.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0F_vqCLnq2ysivJ1dlXzyQ_-74.215789_40.545049_0_351.49.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0GHazbXwLeDW3RPixO5nfg_-74.209812_40.535462_0_352.63.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0GI3kL4kLoqieE0tUWzpEA_-74.214307_40.551976_0_163.30.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0GI3kL4kLoqieE0tUWzpEA_-74.214307_40.551976_0_343.30.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0H3GT4KcXsgPhe6vwCEqEg_-74.225155_40.511937_0_252.72.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0HG7bSTsHvgty3-gkURKlQ_-74.23862_40.506903_0_76.76.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0HkyeGJJBU4p0WKvPnONuA_-74.198811_40.543669_0_251.89.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0HkyeGJJBU4p0WKvPnONuA_-74.198811_40.543669_0_71.89.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0hM5I6uvIYJs1rumpXoBwA_-74.24893_40.5066_0_81.11.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0Hmsyu7k_E74m2uHNrHyOg_-74.207266_40.536638_0_160.92.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0Hmsyu7k_E74m2uHNrHyOg_-74.207266_40.536638_0_340.92.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0hSHMfd5OLdJ6Ms0_GDN6A_-74.195178_40.518044_0_268.11.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0ia5V3JZ2LT8gSUxlvngig_-74.198262_40.542869_0_249.82.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0ia5V3JZ2LT8gSUxlvngig_-74.198262_40.542869_0_69.82.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0IbbXT9J-3neC2pNJ33guQ_-74.216175_40.541331_0_354.68.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0IcoswB9I7RBRFK1zHHTYA_-74.216113_40.523957_0_174.58.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0icTgKD-MHWgXAIAqNyamQ_-74.226462_40.528885_0_296.74.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0j8zsxtXleJEpacSyHv_fg_-74.213906_40.543774_0_178.62.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0JlZH-mPNtmIxL-49zs_Pw_-74.196667_40.549083_0_56.54.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0JvDNGZ05yNc5u9rvEK0Gw_-74.197568_40.547939_0_164.38.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0JvDNGZ05yNc5u9rvEK0Gw_-74.197568_40.547939_0_344.38.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0jVwP8_lldOmk_cjmNemsw_-74.209331_40.546552_0_131.56.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0jVwP8_lldOmk_cjmNemsw_-74.209331_40.546552_0_311.56.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0kcON6MdYobLGsGpwMBfKw_-74.209607_40.545699_0_253.11.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0kcON6MdYobLGsGpwMBfKw_-74.209607_40.545699_0_73.11.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0KvHMEeUNhE5i0IPNVTnrw_-74.196801_40.515741_0_265.12.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0KvHMEeUNhE5i0IPNVTnrw_-74.196801_40.515741_0_85.12.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0KyKPJh8IPmZN79Mtv7nHg_-74.244955_40.503413_0_256.11.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0KyKPJh8IPmZN79Mtv7nHg_-74.244955_40.503413_0_76.11.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0l0cIBnriNda5d2WEoUfIw_-74.247547_40.502435_0_256.70.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0l0cIBnriNda5d2WEoUfIw_-74.247547_40.502435_0_76.70.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0lBtJ6bu00A9yOQNlB--RA_-74.207023_40.531978_0_259.04.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0lBtJ6bu00A9yOQNlB--RA_-74.207023_40.531978_0_79.04.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0LeQWzUTlpBlmvsm_2m3vA_-74.210904_40.552996_0_344.27.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0LEVoHcNw0waFGqR3ZUIkg_-74.249271_40.501966_0_255.03.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0LEVoHcNw0waFGqR3ZUIkg_-74.249271_40.501966_0_75.03.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0lOgtXs6bQAnLacTpPl9AA_-74.250541_40.513958_0_327.85.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0lYmdsd5PaJgBj04TT5ZNg_-74.23897_40.499896_0_253.93.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0Lzs7ilageoP2jpoua6EuA_-74.230261_40.527193_0_93.52.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0m1AgFx6lGyW1LAkXq2Hbg_-74.243144_40.507261_0_344.51.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0mAEQxP3X5nvzK6WXuq3uw_-74.207448_40.533422_0_258.92.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0mh3heLwhT1ixoip5zojlw_-74.208163_40.528423_0_351.63.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0MiP5y2atXrbFFBTsTgjMA_-74.218596_40.525907_0_101.49.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0MiP5y2atXrbFFBTsTgjMA_-74.218596_40.525907_0_281.49.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0MmDSXPJvifa_tOv9BLKUA_-74.249059_40.511327_0_234.71.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0MQh60UTc9cbljCLlwkQJA_-74.246487_40.502214_0_255.69.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0MQh60UTc9cbljCLlwkQJA_-74.246487_40.502214_0_75.69.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0MX1cP5a5Qf6m9U3npW8-A_-74.252154_40.507053_0_276.93.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0MX1cP5a5Qf6m9U3npW8-A_-74.252154_40.507053_0_96.93.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0mxDoZYYb4ZZC2xQJkMG8A_-74.219803_40.54794_0_165.43.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0mYRgiMl15N7W0UKCi0ORQ_-74.209314_40.539481_0_76.50.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0n0pPw_KRv3I0p46vPaZIg_-74.251749_40.510686_0_131.19.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0n0pPw_KRv3I0p46vPaZIg_-74.251749_40.510686_0_311.19.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0N7lmcdna6770s8MMuyAyA_-74.210603_40.545725_0_254.12.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0N7lmcdna6770s8MMuyAyA_-74.210603_40.545725_0_74.12.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0nsmu58QYUlv7Iip3afu9w_-74.203471_40.536177_0_159.28.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0ny4cwCA5T4s-Xt45vQcvQ_-74.239211_40.530906_0_277.04.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0ny4cwCA5T4s-Xt45vQcvQ_-74.239211_40.530906_0_97.04.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0o1GJuzD0H9A7CDKS-RcPw_-74.220273_40.547847_0_200.90.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0OBSa7SmbltO25xvz9HYcw_-74.196782_40.531856_0_343.85.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0oEVCcnAL1XdurnjvegVKQ_-74.197046_40.537007_0_249.70.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0oEVCcnAL1XdurnjvegVKQ_-74.197046_40.537007_0_69.70.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0ogyb8WgHp8UdxQmWyB8Cg_-74.222247_40.531617_0_101.18.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0ogyb8WgHp8UdxQmWyB8Cg_-74.222247_40.531617_0_281.18.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0OzO41Yn8EecgDgrjtzdfQ_-74.206566_40.523679_0_268.65.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0p1AqsugejQB98fpkPqW9g_-74.217648_40.538911_0_94.25.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0PDU-wgqOxUR1aOI6k4NMQ_-74.207712_40.536516_0_161.58.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0PeZZrzzYiWst481jteWwg_-74.240446_40.50137_0_255.70.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0PqfZZnYCEC8eKM9ZgUitA_-74.207716_40.519564_0_127.22.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0PqfZZnYCEC8eKM9ZgUitA_-74.207716_40.519564_0_307.22.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0Pu1VVE9OwiJG3W0RoVvlg_-74.207621_40.534003_0_78.47.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0q3yDaut7lSTHBg5pMmQbg_-74.195231_40.550665_0_340.94.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0q6P1neJbhANrxHRaQMCYQ_-74.201833_40.530556_0_157.51.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0q6P1neJbhANrxHRaQMCYQ_-74.201833_40.530556_0_337.51.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0Qa2k-EHKeAyzbQhL0nXTw_-74.24806_40.503939_0_77.14.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0qBwtptui1D6Gl0MYb2HZg_-74.206104_40.534684_0_340.06.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0QcLd_veyyRG2wBnDOgeZw_-74.210566_40.53538_0_172.25.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0QcLd_veyyRG2wBnDOgeZw_-74.210566_40.53538_0_352.25.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0qh7AFTadCHzRFlASk7HYQ_-74.221961_40.537435_0_353.58.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0RbY2LpjoMtTN6v_CsiY9w_-74.198183_40.518975_0_345.59.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0RHuprhOkwvaYJRs-YXIzA_-74.239996_40.511802_0_328.01.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0rkVkzzEsV1o6K8R-Qg6ng_-74.248182_40.507441_0_260.21.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0rkVkzzEsV1o6K8R-Qg6ng_-74.248182_40.507441_0_80.21.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0rObL6N5t8bStHBkSzxTOA_-74.205989_40.530174_0_160.38.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0rObL6N5t8bStHBkSzxTOA_-74.205989_40.530174_0_340.38.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0RRNHozyEoeGSCNyYtQhCg_-74.237804_40.50435_0_73.65.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0SJgOPjKNCRvIFPQPYfV-Q_-74.209251_40.54912_0_164.94.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0SJgOPjKNCRvIFPQPYfV-Q_-74.209251_40.54912_0_344.94.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0SNrJe_jciabaJ0zXpRleA_-74.198107_40.53614_0_158.33.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0sQZouDCO2BznjA5ElMmJQ_-74.196543_40.554875_0_55.41.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0tj0PHWnMaBJrG__6gxU0w_-74.195442_40.51522_0_234.80.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0toiLCUqCd-QE7B_kKHMMg_-74.217942_40.532087_0_257.19.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0Tp004jrb0qgyTnMdGkQ9g_-74.238906_40.502493_0_251.93.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0tpkrHY2G73D7nftO97pMA_-74.207249_40.532711_0_264.08.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0tpkrHY2G73D7nftO97pMA_-74.207249_40.532711_0_84.08.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0TS7fgCLDXetWaKC7apyyg_-74.219767_40.541912_0_347.49.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0u6bKQGsIl5Y7impPfhpnw_-74.230537_40.509333_0_75.64.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0u81tm5ltmXUfPOKxTfUEg_-74.208477_40.540096_0_340.36.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0uAvaIE-q1-QtoGgzesO5w_-74.215337_40.54363_0_175.54.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0uAvaIE-q1-QtoGgzesO5w_-74.215337_40.54363_0_355.54.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0UDsZMxz6AyF62txcScDcA_-74.217394_40.527176_0_265.79.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0UGP7ZB-Hid6ZAl70JYowg_-74.211596_40.541403_0_174.99.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0uHz0zWVgfUfsdvDp9mdGQ_-74.212007_40.521796_0_168.95.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0umLmIveCOGfTkff0AZRgw_-74.216545_40.54943_0_165.52.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0umLmIveCOGfTkff0AZRgw_-74.216545_40.54943_0_345.52.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0V9-FS6AKa17VJ1EY0xniQ_-74.240582_40.504602_0_258.41.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0V9-FS6AKa17VJ1EY0xniQ_-74.240582_40.504602_0_78.41.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0vCx23v8PtICkhhZRk_x4g_-74.200861_40.538426_0_341.55.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0ViwL4ChUKZIblVAB8W2mw_-74.230602_40.509165_0_254.85.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0VMGM53rTA7mYffyp8HV1Q_-74.242691_40.507874_0_255.15.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\0VMGM53rTA7mYffyp8HV1Q_-74.242691_40.507874_0_75.15.txt',
# ...
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\2xLAMEEpPtll0WxAiXVHlQ_-74.199812_40.549856_0_341.50.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\2Xta28JVwFQA6k8suVk0MQ_-74.205159_40.541781_0_160.35.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\2xW_AJLdYLdsTylvMamS-A_-74.252244_40.511278_0_144.89.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\2YCsrpevFS8N68QGYpeyXw_-74.212023_40.549327_0_58.83.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\2Yh6XXDHXX4mczJp4BSMSw_-74.247207_40.501436_0_256.15.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\2Yh6XXDHXX4mczJp4BSMSw_-74.247207_40.501436_0_76.15.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\2YlFDcoek9GO_DVj4csJ8g_-74.207532_40.533711_0_255.21.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\2YlFDcoek9GO_DVj4csJ8g_-74.207532_40.533711_0_75.21.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\2YXBcv4eoChJFhiczCBDfQ_-74.209539_40.545522_0_254.95.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\2YXBcv4eoChJFhiczCBDfQ_-74.209539_40.545522_0_74.95.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\2YY-WsZMAlNjRMbnXGw3UA_-74.212304_40.555656_0_332.38.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\2ZbpEtOPHZSAVEqYny8ikA_-74.208173_40.556978_0_325.90.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\2zBQfK_gOdRyVVrQvjao3w_-74.207561_40.52797_0_267.84.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\2zBQfK_gOdRyVVrQvjao3w_-74.207561_40.52797_0_87.84.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\2zkFzhzQaeLlSlypLiHMhg_-74.216899_40.534675_0_345.62.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\2zKMCDCXQiMCu5hhnxWKYw_-74.21544_40.534843_0_354.18.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\2zn9uU0lQX5yXj-aaYVI5g_-74.207654_40.539562_0_160.72.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\2zn9uU0lQX5yXj-aaYVI5g_-74.207654_40.539562_0_340.72.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\2_0q-c7rNE2j_JHcNCT5ew_-74.248695_40.505779_0_75.81.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\2_tBCnPApNyNpIr2W0nMXg_-74.247999_40.506718_0_259.42.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3-TUYh_S76TrvjAMa1SDaQ_-74.245201_40.51168_0_54.10.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\30XPXJ1ovZ2x7hvwIIqnLQ_-74.248183_40.506257_0_352.54.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\30zl-8rHGGXNi69lYDOI4g_-74.195527_40.547758_0_159.09.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\317u3UBBtEHuo8Z8rVCGHg_-74.196325_40.531977_0_344.83.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\31EJ1bX2xQbinBsqMGL74A_-74.208871_40.519395_0_68.90.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\31Lr3FQMXzoOuvYK0sUq9Q_-74.213537_40.524569_0_263.89.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\31NEq8ZvFWysLBCJdUp_eg_-74.210501_40.553751_0_162.00.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\31pIcyPwi7OS6x0Qlf7Ktg_-74.217658_40.539713_0_88.62.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\31R8wZa19NYrbMnNcfpXgQ_-74.243404_40.501583_0_253.59.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\31R8wZa19NYrbMnNcfpXgQ_-74.243404_40.501583_0_73.59.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\32PYbu6vsKZnl_Z4yuy5Hw_-74.209011_40.538542_0_256.83.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\32PYbu6vsKZnl_Z4yuy5Hw_-74.209011_40.538542_0_76.83.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\32qFz5FIXDTZcBwksK27eQ_-74.223805_40.537411_0_90.65.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\32VRIRxd043Lb6IHGVQHXg_-74.238812_40.502223_0_255.94.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\339zx8dsMp3bB2kGq5sJQw_-74.233495_40.50806_0_253.93.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\339zx8dsMp3bB2kGq5sJQw_-74.233495_40.50806_0_73.93.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\33RaChPNQ0PrjMSth7vw9A_-74.246625_40.503846_0_165.51.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\33wJ3MCmuivzdafTRgb3rA_-74.246369_40.501866_0_255.88.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\33wJ3MCmuivzdafTRgb3rA_-74.246369_40.501866_0_75.88.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\344kJajkuQFrmgi9D3HrZA_-74.215613_40.525396_0_269.26.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\34ThReiJuhOMf52jRJG3Ig_-74.205694_40.520017_0_167.86.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\34ThReiJuhOMf52jRJG3Ig_-74.205694_40.520017_0_347.86.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\35DJUdXheDXyvp2FJsfd8g_-74.216174_40.527282_0_249.89.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\376PFxIZF4deD5OngANpxQ_-74.22068_40.547022_0_163.74.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\37IEJ-GLuhuYlf0fhcackw_-74.231037_40.510761_0_78.66.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\37LnsFAmS3bSyLFYOlyyNQ_-74.205588_40.530971_0_160.29.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\380gLiDFhJ4UZYqzlfZ16Q_-74.2307_40.505011_0_166.96.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\390t9Au80WKw5byUco29lw_-74.244436_40.498951_0_343.50.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\39eE4stlsxMCeNIYjOeOcw_-74.20846_40.521456_0_171.82.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\39jVGQPvD3NA-L707ofdEg_-74.253146_40.505983_0_96.04.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\39Yo-iZRXxcwyzlpKL3I1A_-74.221351_40.548425_0_299.64.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3A9COskxCbTI049lbk8Xqw_-74.197828_40.53472_0_340.58.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3aaJvnulRwqgdZ1BtL0TVw_-74.229586_40.524366_0_279.63.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3aaJvnulRwqgdZ1BtL0TVw_-74.229586_40.524366_0_99.63.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3aFb1yVLdecrYxZcxC13IA_-74.20944_40.520791_0_76.44.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3AVAcjLMTdYLHtCwVD6oGA_-74.199746_40.527746_0_231.29.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3b079lCkWuoWjkgNr48blA_-74.249524_40.512614_0_148.09.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3b1EpUqWqnEMdsgHXag6Cg_-74.200026_40.545363_0_163.82.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3b1EpUqWqnEMdsgHXag6Cg_-74.200026_40.545363_0_343.82.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3BCA864iDLX3ayPSltv0LQ_-74.239469_40.536757_0_12.03.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3BeF4lAfET3bdeCjkUYwyQ_-74.206255_40.533883_0_163.59.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3bMcJI4OAL6bTk22WDRTQg_-74.211886_40.555826_0_333.52.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3bWVI1RHh4fN2sxo0iGjxg_-74.239178_40.532857_0_226.44.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3bWVI1RHh4fN2sxo0iGjxg_-74.239178_40.532857_0_46.44.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3c7UwdXpTkK0vPtPci6mjA_-74.199817_40.548178_0_69.19.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3CC0yQggpBlI1KOG2w3Xbg_-74.241504_40.498834_0_80.24.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3cH8mLh--8qCCKpCYXiOUg_-74.241862_40.512725_0_52.49.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3cLxg7DmTb8Rfr65yyNOSQ_-74.199486_40.541267_0_250.86.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3cLxg7DmTb8Rfr65yyNOSQ_-74.199486_40.541267_0_70.86.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3CqHci0wzioXAkHwm7uRag_-74.252027_40.51036_0_292.69.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3cSxBLzLmjSIvbBGTbbVPw_-74.23911_40.503098_0_77.36.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3cVhE1bOd_nYJhu0Jdmquw_-74.195303_40.544567_0_149.18.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3cVxJVB7zHwg91i9uUmEgw_-74.209081_40.539937_0_160.67.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3DFE4-i97fYt5X_ISrTaoA_-74.249364_40.504961_0_256.25.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3DFE4-i97fYt5X_ISrTaoA_-74.249364_40.504961_0_76.25.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3DkoZPnzdylz8ENaKVXFsA_-74.226747_40.530005_0_6.14.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3dMBg6h0X7L6TMY1TOi3Gw_-74.19779_40.554996_0_130.61.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3dMBg6h0X7L6TMY1TOi3Gw_-74.19779_40.554996_0_310.61.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3Dqm03bOZm6Jz_rWz77kOg_-74.195903_40.547652_0_159.41.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3EE0oZ0maEEAxTrfnzsM4w_-74.199263_40.556992_0_231.40.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3EE0oZ0maEEAxTrfnzsM4w_-74.199263_40.556992_0_51.40.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3eFUskL64AR-lCymiMKsjA_-74.23577_40.515996_0_217.76.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3eKA0S9Wpdbp8DK5_7Q5wA_-74.2429_40.50569_0_75.93.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3EtxcELDglKvmZK_RKxSew_-74.245817_40.501366_0_344.56.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3EvslXj5JRogM17HhDL7Ag_-74.205363_40.5422_0_245.53.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3EvslXj5JRogM17HhDL7Ag_-74.205363_40.5422_0_65.53.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3FA2fVxwMnbXCs4bQI1kcw_-74.21705_40.544044_0_164.53.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3FA2fVxwMnbXCs4bQI1kcw_-74.21705_40.544044_0_344.53.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3faZDuW3DQZfanwF8ccCHw_-74.202201_40.523443_0_166.69.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3faZDuW3DQZfanwF8ccCHw_-74.202201_40.523443_0_346.69.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3fbm2nc6RRM_3gEBYCHxow_-74.239061_40.500166_0_256.27.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3fbm2nc6RRM_3gEBYCHxow_-74.239061_40.500166_0_76.27.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3fIpf4kl0yWbKBmtesJtzg_-74.196887_40.536677_0_70.71.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3flh5G9wH_Nu_zYWEYXhLQ_-74.195386_40.541464_0_161.84.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3fOBALM4m2jLBfFywApJyg_-74.25082_40.513151_0_61.02.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3FsAcgAaxU0Teo-tIuRG7Q_-74.227861_40.524488_0_183.21.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3fX4L5IA3ngzsCSnhR3Etg_-74.239359_40.53002_0_277.99.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3FY-AUTyAhKHzbdZvYhiOA_-74.209686_40.543561_0_352.72.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3gQgRteZn8vVNyQvz3QlxA_-74.253602_40.5081_0_301.63.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3Gu9ogpIYD6VhC4F3AI0Cw_-74.209225_40.541675_0_354.95.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3GvepEyKjCGUGKLBj_MoQg_-74.211855_40.529228_0_160.73.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3GYsSjmoq2v9BJKhQLPC7w_-74.242992_40.505958_0_75.13.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3HD-vLRtY_l-wN2y0rfF6w_-74.217255_40.523084_0_355.06.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3hdeqiDBqlWs8wkeanwmvQ_-74.242454_40.507222_0_254.33.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3hdeqiDBqlWs8wkeanwmvQ_-74.242454_40.507222_0_74.33.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3hkwQFrtEYb07FhZ1haV7w_-74.196929_40.535715_0_161.31.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3hkwQFrtEYb07FhZ1haV7w_-74.196929_40.535715_0_341.31.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3HlN3XsErVWVKC-yi8uOwA_-74.240681_40.504895_0_260.86.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3HlN3XsErVWVKC-yi8uOwA_-74.240681_40.504895_0_80.86.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3hSafi8AhysgyoOXEf20Jg_-74.196905_40.531824_0_170.16.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3hSafi8AhysgyoOXEf20Jg_-74.196905_40.531824_0_350.16.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3igbAZnGqoPDmayHebB62g_-74.252341_40.505817_0_276.09.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3igbAZnGqoPDmayHebB62g_-74.252341_40.505817_0_96.09.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3JVizB5e2Sj3wzb890p5cQ_-74.202184_40.530459_0_159.44.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3JVizB5e2Sj3wzb890p5cQ_-74.202184_40.530459_0_339.44.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3JYg2smEIaAxcL4nvTvULg_-74.214667_40.550003_0_75.92.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3KaM__qR8b80Lbz3LNMb-g_-74.236721_40.525069_0_177.96.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3KD2h8vOu0Sh0lFiP0X9Ow_-74.208696_40.512923_0_320.85.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3kGq5Ofjf4QxObKTsTfU3Q_-74.199768_40.535678_0_341.32.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3Khm06hURgBi25N_Xau1gA_-74.210833_40.517824_0_348.90.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3KR0TOjQvZ54ofNhTW7t7g_-74.19891_40.536696_0_160.30.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3KR0TOjQvZ54ofNhTW7t7g_-74.19891_40.536696_0_340.30.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3Kws57AMbTXMHJ8_kNGPoQ_-74.197552_40.539335_0_341.56.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3kY1Nh6Xj7hauRXM3-WfHg_-74.196365_40.555627_0_142.58.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3kY1Nh6Xj7hauRXM3-WfHg_-74.196365_40.555627_0_322.58.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3L7nIr9w_BmRks3H099P4g_-74.244666_40.508688_0_250.96.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3LDPqFcRf62_U_8HFTpjGA_-74.201901_40.55491_0_251.19.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3LDPqFcRf62_U_8HFTpjGA_-74.201901_40.55491_0_71.19.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3LKlefN19CboLs95O27X_A_-74.20166_40.536681_0_160.06.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3LKlefN19CboLs95O27X_A_-74.20166_40.536681_0_340.06.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3lL0xk9JLG4vtPVsXqW8Xg_-74.251704_40.506897_0_308.16.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3LTh84HBqKk20aP2fg_0Lw_-74.21188_40.537149_0_85.72.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3lxjIyziiyYO7CLgk_BbvA_-74.204437_40.515646_0_320.56.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3mb_Vo1l7lf360dYV8gLiA_-74.212973_40.540286_0_275.68.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3Mw37EhJU4ExvsRiCUQ_jg_-74.240006_40.51083_0_80.36.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3MxolvqvPVUgRQ0PetnZpQ_-74.236729_40.511718_0_256.09.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3MxolvqvPVUgRQ0PetnZpQ_-74.236729_40.511718_0_76.09.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3n1UGwqoFOzFJbIhSe8wkw_-74.211502_40.53886_0_172.13.txt',
#  'K:\\Research\\Trees\\NewYorkCity_test\\tree_detected\\3Nd2uy684f-u55w7H_gKBQ_-74.24357_40.509557_0_254.23.txt',
#  ...]

# %%
wt = open(r'K:\Research\Trees\NewYorkCity_test\merged_trees.txt', 'w')
wt.writelines("")

# %%
#! /usr/bin/env python
# -*- coding: utf-8 -*-
"""
Run a YOLO_v3 style detection model on test images.
"""

import colorsys
import os
from timeit import default_timer as timer
import progressbar
import numpy as np
from keras import backend as K
from keras.models import load_model
from keras.layers import Input
from PIL import Image, ImageFont, ImageDraw

from yolo3.model import yolo_eval, yolo_body, tiny_yolo_body
from yolo3.utils import letterbox_image
import os
import glob
import pandas as pd
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
from keras.utils import multi_gpu_model
gpu_num=1
isDrawBox = True

class YOLO(object):
    def __init__(self):
        # Huan
        # self.model_path = r'model_data/RS/yolo.h5.h5'
        # self.anchors_path = r'model_data\house_anchors.txt'
        # self.classes_path = r'D:\YOLO\keras-yolo3-master\model_data\addre_classes.txt'
        self.model_path = 'model_data/trunk_trained_weights_final.h5' # model path or trained weights path
        self.anchors_path = 'model_data/yolo_anchors.txt'
        self.classes_path = 'model_data/coco_classes.txt'
        self.score = 0.005
        self.iou = 0.01
        self.class_names = self._get_class()
        self.anchors = self._get_anchors()
        self.sess = K.get_session()
        self.model_image_size = (416, 416) # fixed size or (None, None), hw
        self.boxes, self.scores, self.classes = self.generate()
        isDrawBox = True




    def _get_class(self):
        classes_path = os.path.expanduser(self.classes_path)
        with open(classes_path) as f:
            class_names = f.readlines()
        class_names = [c.strip() for c in class_names]
        return class_names

    def _get_anchors(self):
        anchors_path = os.path.expanduser(self.anchors_path)
        with open(anchors_path) as f:
            anchors = f.readline()
        anchors = [float(x) for x in anchors.split(',')]
        return np.array(anchors).reshape(-1, 2)

    def generate(self):
        model_path = os.path.expanduser(self.model_path)
        assert model_path.endswith('.h5'), 'Keras model or weights must be a .h5 file.'

        # Load model, or construct model and load weights.
        num_anchors = len(self.anchors)
        num_classes = len(self.class_names)
        is_tiny_version = num_anchors==6 # default setting
        try:
            self.yolo_model = load_model(model_path, compile=False)
        except:
            self.yolo_model = tiny_yolo_body(Input(shape=(None,None,3)), num_anchors//2, num_classes) \
                if is_tiny_version else yolo_body(Input(shape=(None,None,3)), num_anchors//3, num_classes)
            self.yolo_model.load_weights(self.model_path) # make sure model, anchors and classes match
        else:
            assert self.yolo_model.layers[-1].output_shape[-1] == \
                num_anchors/len(self.yolo_model.output) * (num_classes + 5), \
                'Mismatch between model and given anchor and class sizes'

        print('{} model, anchors, and classes loaded.'.format(model_path))

        # Generate colors for drawing bounding boxes.
        hsv_tuples = [(x / len(self.class_names), 1., 1.)
                      for x in range(len(self.class_names))]
        self.colors = list(map(lambda x: colorsys.hsv_to_rgb(*x), hsv_tuples))
        self.colors = list(
            map(lambda x: (int(x[0] * 255), int(x[1] * 255), int(x[2] * 255)),
                self.colors))
        np.random.seed(10101)  # Fixed seed for consistent colors across runs.
        np.random.shuffle(self.colors)  # Shuffle colors to decorrelate adjacent classes.
        np.random.seed(None)  # Reset seed to default.

        # Generate output tensor targets for filtered bounding boxes.
        self.input_image_shape = K.placeholder(shape=(2, ))
        if gpu_num>=2:
            self.yolo_model = multi_gpu_model(self.yolo_model, gpus=gpu_num)
        boxes, scores, classes = yolo_eval(self.yolo_model.output, self.anchors,
                len(self.class_names), self.input_image_shape,
                score_threshold=self.score, iou_threshold=self.iou)
        return boxes, scores, classes

    def detect_image(self, image):
        start = timer()

        if self.model_image_size != (None, None):
            assert self.model_image_size[0]%32 == 0, 'Multiples of 32 required'
            assert self.model_image_size[1]%32 == 0, 'Multiples of 32 required'
            boxed_image = letterbox_image(image, tuple(reversed(self.model_image_size)))
        else:
            new_image_size = (image.width - (image.width % 32),
                              image.height - (image.height % 32))
            boxed_image = letterbox_image(image, new_image_size)
        image_data = np.array(boxed_image, dtype='float32')

        print(image_data.shape)
        image_data /= 255.
        image_data = np.expand_dims(image_data, 0)  # Add batch dimension.

        out_boxes, out_scores, out_classes = self.sess.run(
            [self.boxes, self.scores, self.classes],
            feed_dict={
                self.yolo_model.input: image_data,
                self.input_image_shape: [image.size[1], image.size[0]],
                K.learning_phase(): 0
            })

        print('Found {} boxes for {}'.format(len(out_boxes), 'img'))

        font = ImageFont.truetype(font='font/FiraMono-Medium.otf',
                    size=np.floor(3e-2 * image.size[1] + 0.5).astype('int32'))
        thickness = (image.size[0] + image.size[1]) // 300

        for i, c in reversed(list(enumerate(out_classes))):
            predicted_class = self.class_names[c]
            box = out_boxes[i]
            score = out_scores[i]

            label = '{} {:.2f}'.format(predicted_class, score)
            draw = ImageDraw.Draw(image)
            label_size = draw.textsize(label, font)

            top, left, bottom, right = box
            top = max(0, np.floor(top + 0.5).astype('int32'))
            left = max(0, np.floor(left + 0.5).astype('int32'))
            bottom = min(image.size[1], np.floor(bottom + 0.5).astype('int32'))
            right = min(image.size[0], np.floor(right + 0.5).astype('int32'))
            print(label, (left, top), (right, bottom))

            if top - label_size[1] >= 0:
                text_origin = np.array([left, top - label_size[1]])
            else:
                text_origin = np.array([left, top + 1])

            # My kingdom for a good redistributable image drawing library.
            for i in range(thickness):
                draw.rectangle(
                    [left + i, top + i, right - i, bottom - i],
                    outline=self.colors[c])
            draw.rectangle(
                [tuple(text_origin), tuple(text_origin + label_size)],
                fill=self.colors[c])
            draw.text(text_origin, label, fill=(0, 0, 0), font=font)
            del draw

        end = timer()
        print(end - start)
        return image

    def detect_image_single(self, file, isDrawBox):
        try:
            image = Image.open(file)
            width, height = image.size
        except Exception as e:
            print("Error: ", repr(e))
            return None
        if self.model_image_size != (None, None):
            assert self.model_image_size[0]%32 == 0, 'Multiples of 32 required'
            assert self.model_image_size[1]%32 == 0, 'Multiples of 32 required'
            boxed_image = letterbox_image(image, tuple(reversed(self.model_image_size)))
        else:
            new_image_size = (image.width - (image.width % 32),
                              image.height - (image.height % 32))
            boxed_image = letterbox_image(image, new_image_size)
        image_data = np.array(boxed_image, dtype='float32')

        #print(image_data.shape)
        image_data /= 255.
        image_data = np.expand_dims(image_data, 0)  # Add batch dimension.

        out_boxes, out_scores, out_classes = self.sess.run(
            [self.boxes, self.scores, self.classes],
            feed_dict={
                self.yolo_model.input: image_data,
                self.input_image_shape: [image.size[1], image.size[0]],
                K.learning_phase(): 0
            })

        # print('type of out_boxes: ', type(out_boxes))
        # print('type of out_scores: ', type(out_scores))
        # print('type of out_classes: ', type(out_classes))
        #
        # print(zip(out_boxes, out_scores, out_classes))
        # for i, (a, b, c) in enumerate(zip(out_boxes, out_scores, out_classes)):
        #     print(i, a, b, self.class_names[c])

        #series = pd.Series(out_boxes[:, 0])
        df = pd.DataFrame(out_boxes)
        #df = df.rename(columns={'0':'top', '1':'left', '2':'bottom','3':'right'})
        df.columns = ['top', 'left', 'bottom', 'right']
        #print(np.floor(df['top'] + 0.5))
        df['top'] = np.maximum(0, np.floor(df['top'] + 0.5)).astype('int32')
        df['left'] = np.maximum(0, np.floor(df['left'] + 0.5)).astype('int32')
        df['bottom'] = np.minimum(height, np.floor(df['bottom'] + 0.5)).astype('int32')
        df['right'] = np.minimum(width, np.floor(df['right'] + 0.5)).astype('int32')
        #print(np.minimum(0, np.floor(df['top'] + 0.5)))

        class_names = []
        for i in out_classes:
            class_names.append(self.class_names[i])
        df['class_name'] = class_names
        df['score'] = out_scores
        df['out_classes'] = out_classes
        df['image'] = os.path.basename(file)
        df['area_pct'] = (df['bottom'] - df['top']) * (df['right'] - df['left']) / (width * height)
        df['area_pct'] = df['area_pct'].abs()
        # print(df)
       # print(df['class_name'])
        if isDrawBox:
            font = ImageFont.truetype(font='font/FiraMono-Medium.otf',
                                      size=np.floor(3e-2 * image.size[1] + 0.5).astype('int32'))
            thickness = (image.size[0] + image.size[1]) // 300

            for i, c in reversed(list(enumerate(out_classes))):
                predicted_class = self.class_names[c]
                box = out_boxes[i]
                score = out_scores[i]

                label = '{} {:.2f}'.format(predicted_class, score)
                draw = ImageDraw.Draw(image)
                label_size = draw.textsize(label, font)
                #
                top, left, bottom, right = box
                top = max(0, np.floor(top + 0.5).astype('int32'))
                left = max(0, np.floor(left + 0.5).astype('int32'))
                bottom = min(image.size[1], np.floor(bottom + 0.5).astype('int32'))
                right = min(image.size[0], np.floor(right + 0.5).astype('int32'))

                if top - label_size[1] >= 0:
                    text_origin = np.array([left, top - label_size[1]])
                else:
                    text_origin = np.array([left, top + 1])

                # My kingdom for a good redistributable image drawing library.
                for i in range(thickness):
                    draw.rectangle(
                        [left + i, top + i, right - i, bottom - i],
                        outline=self.colors[c])


                # if df.ix[i, 'top'] - label_size[1] >= 0:
                #     text_origin = np.array([df.ix[i, 'left'], df.ix[i, 'top'] - label_size[1]])
                # else:
                #     text_origin = np.array([df.ix[i, 'left'], df.ix[i, 'top'] + 1])
                #
                # # My kingdom for a good redistributable image drawing library.
                # #print(label, (left, top), (right, bottom))
                # for i in range(thickness):
                #     draw.rectangle(
                #         [df.ix[i, 'left'] + i, df.ix[i, 'top'] + i, df.ix[i, 'right'] - i, df.ix[i, 'bottom'] - i],
                #         outline=self.colors[c])
                draw.rectangle(
                    [tuple(text_origin), tuple(text_origin + label_size)],
                    fill=self.colors[c])
                draw.text(text_origin, label, fill=(0, 0, 0), font=font)
                del draw

        return df, image

    def detect_image_folder(self, folder):
        start = timer()
        all_files = glob.glob(folder + '/*.jpg', recursive=True)
        #df_list = [] # name, label, score, top, left, bottom, right

        print('Image number: ', len(all_files))
        print("Start detect...")
        i = 0
        p = progressbar.ProgressBar()
        # p.start(len(all_files))
        w = open(os.path.join(folder, 'YOLO_label_score0p005.csv'), 'w', newline="")
        w.writelines('top,left,bottom,right,class_name,score,out_classes,image,area_pct\n')
        result_folder = os.path.join(folder, 'Detected')
        for file in all_files:
            #detect_image_single(file)
            try:
                df, image = (self.detect_image_single(file, isDrawBox))
                lines = df.to_csv(header=False, index=False)
                w.writelines(lines)

                if isDrawBox:
                    if not os.path.exists(result_folder):
                        os.mkdir(result_folder)
                    #print(os.path.join(os.path.pardir(file), "Detected"))
                    image.save(os.path.join(result_folder, os.path.basename(file)))
                    #image.show()
            except Exception as e:
                print("Error in processing:", file, repr(e))
            i += 1
            # p.update(i)
        w.close()

        end = timer()
        print('Processing time: %.1f' % (end - start))
        #return pd.concat(df_list)

    def close_session(self):
        self.sess.close()

def detect_img(yolo):
    while True:
        folder = input('Input image folder:')
        try:
           # image = Image.open(img)
            os.path.exists(folder)
        except:
            print('Open Folder Error! Try Again!')
            continue
        else:
            yolo.detect_image_folder(folder)
            print("Finished! ")
            #df.to_csv(, index=False)
            #r_image.show()
    yolo.close_session()



# if __name__ == '__main__':
#     detect_img(YOLO())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-7520ce18a122> in <module>
#       8 import os
#       9 from timeit import default_timer as timer
# ---> 10 import progressbar
#      11 import numpy as np
#      12 from keras import backend as K
#
# ModuleNotFoundError: No module named 'progressbar'

# %%
folder = r'K:\Research\Trees\NewYorkCity_test\google_street_images'
yolo.detect_image_folder(folder)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-4b9e90c0071a> in <module>
#       1 folder = r'K:\Research\Trees\NewYorkCity_test\google_street_images'
# ----> 2 yolo.detect_image_folder(folder)
#
# NameError: name 'yolo' is not defined
