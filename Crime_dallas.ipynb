# %%
import pandas as pd
csv_file = r'K:\OneDrive_NJIT\OneDrive - NJIT\Research\Crime_nightlight\Police_Incidents.csv'
df = pd.read_csv(csv_file)

# %%
df["Location1"] = df["Location1"].str.replace('\n', ' ')

# %%
df
# Out:
#        Incident Number w/year  Year of Incident Service Number ID  Watch  \
# 0                 146854-2017              2017    146854-2017-01      3
# 1                 150391-2015              2015    150391-2015-01      2
# 2                 223131-2018              2018    223131-2018-01      3
# 3                 210404-2015              2015    210404-2015-01      1
# 4                 233068-2015              2015    233068-2015-01      2
# ...                       ...               ...               ...    ...
# 614595            071638-2015              2015    071638-2015-01      1
# 614596            108185-2015              2015    108185-2015-01      3
# 614597            179410-2015              2015    179410-2015-01      3
# 614598            041409-2020              2020    041409-2020-01      1
# 614599            286470-2015              2015    286470-2015-01      1
#
#                 Call (911) Problem  \
# 0       6X - MAJOR DIST (VIOLENCE)
# ...
