# %%
import os
import glob

# %%
folder = r'X:\Shared drives\Group_research\Story_research\Datasets\Huan\**\*.jpg'

# %%
files = glob.glob(folder , recursive=True)
files
# Out:
# ['X:\\Shared drives\\Group_research\\Story_research\\Datasets\\Huan\\train\\cannot_tell\\0_3XKKOYgxDAGi2Nd-3XiDIw_-76.569103_39.347663_0_44.92 - Copy.jpg',
#  'X:\\Shared drives\\Group_research\\Story_research\\Datasets\\Huan\\train\\cannot_tell\\0_3XKKOYgxDAGi2Nd-3XiDIw_-76.569103_39.347663_0_44.92.jpg',
#  'X:\\Shared drives\\Group_research\\Story_research\\Datasets\\Huan\\train\\cannot_tell\\0_4knXILiDQP-mRPyu6tXDSQ_-76.597835_39.371891_0_304.89 - Copy.jpg',
#  'X:\\Shared drives\\Group_research\\Story_research\\Datasets\\Huan\\train\\cannot_tell\\0_4knXILiDQP-mRPyu6tXDSQ_-76.597835_39.371891_0_304.89.jpg',
#  'X:\\Shared drives\\Group_research\\Story_research\\Datasets\\Huan\\train\\cannot_tell\\0_8s4RzVMLhXvRI9KLhvmMzg_-76.670311_39.360258_0_161.44 - Copy.jpg',
#  'X:\\Shared drives\\Group_research\\Story_research\\Datasets\\Huan\\train\\cannot_tell\\0_8s4RzVMLhXvRI9KLhvmMzg_-76.670311_39.360258_0_161.44.jpg',
# ...

# %%
len(files)
# Out:
# 14725

# %%
wt = open(r"X:\Shared drives\Group_research\Story_research\Datasets\Huan\file_list.txt", 'w')
for f in files:
    wt.writelines(f + "\n")
print("done")
# Out:
# done
