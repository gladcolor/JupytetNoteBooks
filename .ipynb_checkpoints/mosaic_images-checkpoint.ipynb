# %%
import numpy
from skimage import io
from PIL import Image
import glob
import os
import matplotlib.pyplot as plt

# %%
all_images = glob.glob(r'K:\Research\Resilience\building_images2\*.jpg')
all_segmented = glob.glob(r'K:\Research\Resilience\building_images2_seg_pspnet_ade20k\*color.png')

# %%
# merge result and image
saved_path = r'K:\Research\Resilience\mosaiced'
#segmented_path = r'D:\OneDrive_NJIT\OneDrive - NJIT\Research\sidewalk\Essex_test\jpg\segmented_1024'
segmented_path = r'K:\Research\Resilience\building_images2_seg_pspnet_ade20k'

segmented_path2 = r'K:\Research\Resilience\building_images2_seg'


for idx, file in enumerate(all_images[:]):
    try:
        mosaiced = Image.new("RGB", (576 * 3, 768))

        image = Image.open(file)
#         image.thumbnail((512*2, 384*2), Image.ANTIALIAS)
        basename = os.path.basename(file)
        segmented_file2 = os.path.join(segmented_path2, basename.replace(".jpg", '.png'))
        basename = os.path.basename(file).replace(".jpg", '_color.png')
        segmented_file = os.path.join(segmented_path, basename)
        segmented = Image.open(segmented_file)
#         w, h = image.size
        #print(w, h, mosaiced.size)

        w, h = image.size
        im = plt.imread(segmented_file)
        #plt.imshow(im)
        #plt.imshow()
        #print(type(im))
        #print(image)
        im = im*255
        im = im.astype(numpy.uint8)
        im = Image.fromarray(im)
        #print(im)
        
        im2 = plt.imread(segmented_file2)
        im2 = im2*255
        im2 = im2.astype(numpy.uint8)
        im2 = Image.fromarray(im2)
        
        mosaiced.paste(image, (0, 0, w, h))
        mosaiced.paste(im, (w, 0, w*2, h))
        mosaiced.paste(im2, (w * 2, 0, w*3, h))
        newfile = os.path.join(saved_path, basename.replace(".png", '_mosaiced.png'))
        #newfile = os.path.join(r'K:\Research\StreetView\essex_seg_samples', )
        mosaiced.save(newfile)

        if idx % 100 == 0:
            print(idx, file)
            plt.imshow(mosaiced)
            plt.show()
    except Exception as e:
        print(e)
        continue
# Out:
# 0 K:\Research\Resilience\building_images2\--2ujEdSU5YZENIoaIyINQ_-71.034985_42.368033_0_112.06.jpg
# [Errno 2] No such file or directory: 'K:\\Research\\Resilience\\building_images2_seg\\-4G2BH3NgiKL0Kly3DC4tA_-70.990155_42.399905_0_115.53.jpg'
# [Errno 2] No such file or directory: 'K:\\Research\\Resilience\\building_images2_seg\\-4r6PIiPHvy7V6TIQaBcTw_-71.067819_42.323416_0_142.24.jpg'
# [Errno 2] No such file or directory: 'K:\\Research\\Resilience\\building_images2_seg\\-8xiaQdqxWvj-VBqnAFlQA_-71.051792_42.364509_0_72.54.jpg'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# D:\Anaconda3\lib\site-packages\PIL\ImageFile.py in _save(im, fp, tile, bufsize)
#     495     try:
# --> 496         fh = fp.fileno()
#     497         fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-a77b1be2be80> in <module>
#      42         newfile = os.path.join(saved_path, basename.replace(".png", '_mosaiced.png'))
#      43         #newfile = os.path.join(r'K:\Research\StreetView\essex_seg_samples', )
# ---> 44         mosaiced.save(newfile)
#      45
#      46         if idx % 100 == 0:
#
# D:\Anaconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2100
#    2101         try:
# -> 2102             save_handler(self, fp, filename)
#    2103         finally:
#    2104             # do what we can to clean up
#
# D:\Anaconda3\lib\site-packages\PIL\PngImagePlugin.py in _save(im, fp, filename, chunk)
#     898         chunk(fp, b"eXIf", exif)
#     899
# --> 900     ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#     901
#     902     chunk(fp, b"IEND", b"")
#
# D:\Anaconda3\lib\site-packages\PIL\ImageFile.py in _save(im, fp, tile, bufsize)
#     508             else:
#     509                 while True:
# --> 510                     l, s, d = e.encode(bufsize)
#     511                     fp.write(d)
#     512                     if s:
#
# KeyboardInterrupt:

# %%
    def test_castesian_to_shperical(self):
#        predict = Image.open(r'O:\OneDrive_NJIT\OneDrive - NJIT\Research\sidewalk\streetview_images\198793_17033785714_-76.741101_38.852598_0_288.png')
        predict = io.imread(
            r'O:\OneDrive_NJIT\OneDrive - NJIT\Research\sidewalk\streetview_images\265746_-74.2180614_40.7864947_0_53_FR.png')

        #print('predict: ', predict)
        #print('predict shape: ', predict.shape)
        predict = np.array(predict)
        sidewalks = np.argwhere(predict == 11)#[:2]
        #sidewalks[0] = (50, 650)   # col, row
        #sidewalks[1] = (638, 290)  # col, row
        print("sidewalks[0]: ", sidewalks[0])
        sidewalks = [tuple(row) for row in sidewalks]

        print("len of sidewalks pixels: ", len(sidewalks))

        sidewalks_sph = GPano.GPano.castesian_to_shperical(GPano.GPano(), sidewalks, 512, 384, 90)
        #sidewalks_sph = [tuple([row[0], row[1] + 99.08]) for row in sidewalks_sph]

        lon = -74.218032
        lat = 40.786579
        pano_heading = 9.25
        pano_pitch = 0.28
        pano_H = 15.42182
        thumb_heading = 53
        thumb_pitch = 0

        obj_json = GPano.GSV_depthmap.getJsonDepthmapfrmLonlat(GPano.GPano(), lon, lat)

        webX, webY = GPano.GSV_depthmap.lonlat2WebMercator( GPano.GSV_depthmap(), lon, lat)
        print("webX, webY:", webX, webY)

        dm = GPano.GSV_depthmap.getDepthmapfrmJson(GPano.GSV_depthmap(), obj_json)
        print("dm[depthmap]: ", dm['depthMap'])
        print("len of dm[depthmap]: ", len(dm['depthMap']))
        pointcloud = GPano.GSV_depthmap.getPointCloud(GPano.GSV_depthmap(), sidewalks_sph,  thumb_heading - pano_heading, pano_pitch + thumb_pitch, dm, lon, lat, pano_H, pano_heading, pano_pitch)
        print('pointcloud:', pointcloud[0])
        print('pointcloud:', pointcloud[1])
        print(pointcloud[11])
        plt_x = [row[0] for row in pointcloud]
        plt_y = [row[1] for row in pointcloud]
        plt.scatter(plt_x, plt_y)
        plt.show()
        with open(r'O:\OneDrive_NJIT\OneDrive - NJIT\Research\sidewalk\streetview_images\pointcloud.csv', 'w') as f:
            f.write('\n'.join('%s,%s,%s,%s' % x for x in pointcloud))

        with open(r'O:\OneDrive_NJIT\OneDrive - NJIT\Research\sidewalk\streetview_images\sidewalk_pixels.csv', 'w') as ff:
            ff.write('\n'.join('%s,%s' % x for x in sidewalks))

        # for row in sidewalks_sph:
        #     print(row)
        dm_w = 512
        dm_h = 216
        #print(sidewalks)
        #print('predict: ', predict)
        #print('sidewalks: ', sidewalks)
        self.assertEqual(True, sidewalks_sph)

# %%
seg = r'_efJTCO_Jz0ul81H__s2FiFew_____-75.33_52.33_60_52.png'
params = os.path.basename(seg)[:-4].split('_')
thumb_panoId = '_'.join(params[:(len(params) - 4)])
print(thumb_panoId)
# Out:
# _efJTCO_Jz0ul81H__s2FiFew____

# %%
import pandas as pd
import glob 
import os
import shutil
files = glob.glob(r'G:\My Drive\Sidewalk_extraction\Essex\panos\*.json')
print("len of files: ", len(files))
# Out:
# len of files:  277283

# %%
saved_path = r'D:\Essex\panos'
# f = open(os.path.join(saved_path, 'json_list.txt'), 'w') 
for idx, file in enumerate(files[:]): 
    basename = os.path.basename(file).replace(".json", '.jpg')
    
#     f.writelines(basename + "\n")
    jpg_file = file.replace(".json", '.jpg')
    print(jpg_file)
    shutil.copyfile(jpg_file, os.path.join(saved_path, basename))
    if idx % 11 == 0:
        print(idx, len(os.path.basename(file)))
# f.close()
# Out:
# G:\My Drive\Sidewalk_extraction\Essex\panos\Qsin_KdBvPNBUsSExW_jGA.jpg
# 0 27
# G:\My Drive\Sidewalk_extraction\Essex\panos\IJfUXDE9hSi1lX5eTLRRmA.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\QDzMO_DG0O6HRquzY4ZLvw.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\rbekB15Q53JXC3Tstbc2IQ.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\qjlFq1L1wlXuGc8yYHT2xg.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\ttPnRhIpz7NJKffLTGaGSQ.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\IR38qfMeCFSzTgqjxnRdhw.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\hpwfBK1xRVKkhDq1NMyrCQ.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\utlFuIcVjkhL85vVtK32sw.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\JSAarKXRO_ecO3sJIFTkFw.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\0iuifU1673IxOH2XkFGQRg.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\XP-1suyjQNzVnlrHODl_cw.jpg
# 11 27
# G:\My Drive\Sidewalk_extraction\Essex\panos\masUB_RqtZumIX-NgNRERQ.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\R7PUdNACzIoWvUOtyB1PUA.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\A-E2th7NU0I5actFG4a3sA.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\99rnqWQCOzfHaqe8CFKOpw.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\7DDFQQBOwzgZ4p_2OCbgZQ.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\diny0xmii55T6SxIHObhrg.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\FM_2jVurXTjg7pxWfa0OQw.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\oz6KwBL13Jc55l4NNN4CxA.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\xp2TVg3aLMeSRht6Af9opw.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\vA5GRgjFzl2usySbkZQ7BA.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\grrI5E_dRkOY-Q9rF0Qohw.jpg
# 22 27
# G:\My Drive\Sidewalk_extraction\Essex\panos\JIkFEKPhA_s7slw1czuKqg.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\0NxTBwtLSWO0zKUEl3Qkiw.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\lxs3fw1ZjWBjdGDMJMw-LA.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\y5nB75bt54RTrrM052IB_w.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\LlzOU1qvVsAU9inoemWKlQ.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\LN3mYNPKS3rbLQLgAImFOg.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\_YP5vDyXfgB-3Fowhu92dA.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\IA0tgailp9PulFhnSOZ1HQ.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\qmz6OInGjcKSA9IxyrY1bA.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\-ka22RYHQYnE8U45AJvX0Q.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\_ZOYPFro5F5vFAT6D5eIeg.jpg
# 33 27
# G:\My Drive\Sidewalk_extraction\Essex\panos\wxUzwK7MHvLi2DoVqcuyMw.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\sGJnJe4AaOWsGeQucZL46A.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\j1MhMm0dilBsYCaHi_l4XQ.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\ZyoWjQo6RN1GxzjvC9fONw.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\mCcS89myi0wlIuJFx62b-g.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\nIyJMFmaQDw3PcuBwhzBmw.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\OPtrk_ok_8w1IEfEF_A_9A.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\aSpRTwcAyMghe2943D7-TQ.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\8YaBfSaPFwbx3-CEZK15Mw.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\RUdxIBBNLYD5OPg5yYiKfg.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\5rZQUq9zAoSEsOFjqSM_qg.jpg
# 44 27
# G:\My Drive\Sidewalk_extraction\Essex\panos\--l23CiozVHMAzPCwLETkA.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\sbcu2SkoRsfg4dlZOfVlHw.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\r0UVQSVTPbK7g2G11iYWeA.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\B1Dzv_malrJx_2yyTLaNdQ.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\6C5YSdi85IcbXj4e8Mpe8A.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\WgTZvmJ2XMAHCu402S3zcw.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\Jt_LZFpope9JimvPEw5acw.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\JHVSUkqztCtJRbHHfwYf7A.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\vW1HXVpzI4SRGROaYovjoQ.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\Uiua9TzPFg2icogZwCBVfw.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\dDxK5MtlZBJU63YROKeURQ.jpg
# 55 27
# G:\My Drive\Sidewalk_extraction\Essex\panos\Fo3KS9c5QiqP7Fk1jiNapw.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\ARrrTj-WrdHLD19u_pHKVQ.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\39xDGmDZrn52xaONNYaiqg.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\0xSZn5_bajmLL6uZZI86lw.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\s3qveDGtHmphvuFYoyEFfw.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\00VtDEKV2w1E7C67d7jurg.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\Y1LDemSSSL3CX7s_NiSLmg.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\0FHAJ_8CRfZWuw6IUAkpDQ.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\Xb6Pm0pij-FItGuD4keh4g.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\EmAFPVa-nfb2SDK6lmBZpQ.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\CDCXIkhXq28nI-tLEd6xbQ.jpg
# 66 27
# G:\My Drive\Sidewalk_extraction\Essex\panos\3tSXoT2Vz-oFZ18U1t3FOQ.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\NcI9DuIv8a6aFlcVmCm9Ng.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\nrGrliDgu3fGCnsJ-JLR3Q.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\0ho-HUx1TMZrfkKL-2VsMQ.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\D9uipatX9UN5FnYUIOU-KA.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\NKrRXp0zdvxKQfVsdfs_xw.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\P8hF1xpypDm8YtyrNtsINg.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\C1Bj8zI2W8VptXSJTyOYIA.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\5lFU2Ut7DIRe-YHPc6DZKw.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\d37uYd3woaOan6dhg456_Q.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\Jk628-K5Uv9WQMtQSxWXKA.jpg
# 77 27
# G:\My Drive\Sidewalk_extraction\Essex\panos\hJAA3dz-nE7NR8Kn34H1sg.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\0unFEmxIZ3wIMLpSbWrDmg.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\LRN6Di74ZmGOK7epCak44Q.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\DsM44UhH76-ke6uJKIqlSw.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\xYP-OZtKpRgvrEKzbCkvQw.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\I5NhKaMevACKdZsgqt-xKQ.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\1ka_p80w7cGSE4A9v6h56w.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\PeXuAo3AxWHcqXCA-jryLw.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\_dATUpsB2VErx0vscjT8gQ.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\wIvMwDXzsRqOsvF7NkBMRw.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\hmu4Q54Er8ajXGvLDbYblw.jpg
# 88 27
# G:\My Drive\Sidewalk_extraction\Essex\panos\PsnNztvy_I8T5ofTN3X2Hw.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\570SpBqYWykYWPBxkuyPqw.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\XVE8w1rwXrxsW4zjbAnxVA.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\Njfby1ptY83avSS22-aW5A.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\41dhTsRkUyw9Gx0uZo_xPA.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\NRwOWj1ggiUY_KioR_cSCQ.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\vdSBvYqsRIJlalgbT8WTZg.jpg
# G:\My Drive\Sidewalk_extraction\Essex\panos\ZtoSbEjaJh1qjVGJ_fBKqA.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-fd46181657ea> in <module>
#       7     jpg_file = file.replace(".json", '.jpg')
#       8     print(jpg_file)
# ----> 9     shutil.copyfile(jpg_file, os.path.join(saved_path, basename))
#      10     if idx % 11 == 0:
#      11         print(idx, len(os.path.basename(file)))
#
# d:\ProgramData\Anaconda3\lib\shutil.py in copyfile(src, dst, follow_symlinks)
#     120         with open(src, 'rb') as fsrc:
#     121             with open(dst, 'wb') as fdst:
# --> 122                 copyfileobj(fsrc, fdst)
#     123     return dst
#     124
#
# d:\ProgramData\Anaconda3\lib\shutil.py in copyfileobj(fsrc, fdst, length)
#      77     """copy data from file-like object fsrc to file-like object fdst"""
#      78     while 1:
# ---> 79         buf = fsrc.read(length)
#      80         if not buf:
#      81             break
#
# KeyboardInterrupt:
