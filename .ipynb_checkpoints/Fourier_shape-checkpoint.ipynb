# %%
import cv2
import scipy
import matplotlib.pyplot as plt
from PIL import Image
from skimage import io
import numpy as np
import scipy.signal
from matplotlib.lines import Line2D
import math
import os
import glob

from math import *
import multiprocessing as mp
 



import logging
import yaml
import logging.config

from pyefd import elliptic_fourier_descriptors
import pyefd

# %%
file = r'K:\Research\CVPR\test\train\label\christchurch_905_vis.tif'

# %%
seg_cv2 = cv2.imread(file, cv2.IMREAD_UNCHANGED)


contoursRaw, hierarchy = cv2.findContours(seg_cv2, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

# %%
len(contoursRaw)
# Out:
# 617

# %%
contoursNONE = [np.squeeze(cont) for cont in contoursRaw]

# %%
len(contoursNONE)
# Out:
# 617

# %%
contoursNONE[1]
# Out:
# array([[1876, 8395],
#        [1875, 8396],
#        [1874, 8397],
#        [1873, 8398],
#        [1872, 8399],
#        [1871, 8400],
#        [1870, 8400],
#        [1869, 8401],
#        [1868, 8402],
#        [1867, 8403],
#        [1866, 8404],
#        [1865, 8404],
#        [1864, 8405],
#        [1863, 8406],
#        [1862, 8407],
#        [1861, 8408],
#        [1860, 8409],
#        [1859, 8409],
#        [1858, 8410],
#        [1857, 8411],
#        [1856, 8412],
#        [1855, 8413],
#        [1854, 8413],
#        [1853, 8414],
#        [1852, 8415],
#        [1851, 8416],
#        [1850, 8417],
#        [1849, 8418],
#        [1848, 8418],
#        [1847, 8419],
#        [1846, 8420],
#        [1845, 8421],
#        [1844, 8422],
#        [1843, 8422],
#        [1842, 8423],
#        [1841, 8424],
#        [1840, 8425],
#        [1839, 8426],
#        [1838, 8427],
#        [1837, 8427],
#        [1836, 8428],
#        [1835, 8429],
#        [1834, 8430],
#        [1833, 8431],
#        [1832, 8431],
#        [1831, 8432],
#        [1830, 8433],
#        [1829, 8434],
#        [1828, 8435],
#        [1829, 8436],
#        [1830, 8437],
#        [1831, 8438],
#        [1832, 8439],
#        [1833, 8440],
#        [1833, 8441],
#        [1834, 8442],
#        [1835, 8443],
#        [1836, 8444],
#        [1837, 8445],
#        [1837, 8446],
#        [1838, 8447],
#        [1839, 8448],
#        [1840, 8449],
#        [1841, 8450],
#        [1842, 8451],
#        [1842, 8452],
#        [1843, 8453],
#        [1844, 8454],
#        [1845, 8455],
#        [1846, 8456],
#        [1846, 8457],
#        [1847, 8458],
#        [1848, 8459],
#        [1849, 8460],
#        [1850, 8461],
#        [1851, 8462],
#        [1851, 8463],
#        [1852, 8464],
#        [1853, 8465],
#        [1854, 8466],
#        [1855, 8467],
#        [1855, 8468],
#        [1856, 8469],
#        [1857, 8470],
#        [1858, 8471],
#        [1859, 8472],
#        [1860, 8473],
#        [1860, 8474],
#        [1861, 8475],
#        [1862, 8476],
#        [1863, 8477],
#        [1864, 8478],
#        [1864, 8479],
#        [1865, 8480],
#        [1866, 8481],
#        [1867, 8482],
#        [1868, 8483],
#        [1869, 8484],
#        [1869, 8485],
#        [1870, 8486],
#        [1871, 8487],
#        [1872, 8488],
#        [1873, 8489],
#        [1873, 8490],
#        [1874, 8491],
#        [1875, 8492],
#        [1876, 8493],
#        [1877, 8494],
#        [1878, 8495],
#        [1878, 8496],
#        [1879, 8497],
#        [1880, 8498],
#        [1881, 8499],
#        [1882, 8500],
#        [1883, 8499],
#        [1884, 8498],
#        [1885, 8497],
#        [1886, 8497],
#        [1887, 8496],
#        [1888, 8495],
#        [1889, 8494],
#        [1890, 8493],
#        [1891, 8492],
#        [1892, 8492],
#        [1893, 8491],
#        [1894, 8490],
#        [1895, 8489],
#        [1896, 8488],
#        [1897, 8488],
#        [1898, 8487],
#        [1899, 8486],
#        [1900, 8485],
#        [1901, 8484],
#        [1902, 8483],
#        [1903, 8483],
#        [1904, 8482],
#        [1905, 8481],
#        [1906, 8480],
#        [1907, 8479],
#        [1908, 8479],
#        [1909, 8478],
#        [1910, 8477],
#        [1911, 8476],
#        [1912, 8475],
#        [1913, 8474],
#        [1914, 8474],
#        [1915, 8473],
#        [1916, 8472],
#        [1917, 8471],
#        [1918, 8470],
#        [1919, 8470],
#        [1920, 8469],
#        [1921, 8468],
#        [1922, 8467],
#        [1923, 8466],
#        [1924, 8465],
#        [1925, 8465],
#        [1926, 8464],
#        [1927, 8463],
#        [1928, 8462],
#        [1929, 8461],
#        [1930, 8461],
#        [1929, 8460],
#        [1928, 8459],
#        [1927, 8458],
#        [1927, 8457],
#        [1926, 8456],
#        [1925, 8455],
#        [1924, 8454],
#        [1923, 8453],
#        [1922, 8452],
#        [1922, 8451],
#        [1921, 8450],
#        [1920, 8449],
#        [1919, 8448],
#        [1918, 8447],
#        [1918, 8446],
#        [1917, 8445],
#        [1916, 8444],
#        [1915, 8443],
#        [1914, 8442],
#        [1913, 8441],
#        [1913, 8440],
#        [1912, 8439],
#        [1911, 8438],
#        [1910, 8437],
#        [1909, 8436],
#        [1909, 8435],
#        [1908, 8434],
#        [1907, 8433],
#        [1906, 8432],
#        [1905, 8431],
#        [1904, 8430],
#        [1904, 8429],
#        [1903, 8428],
#        [1902, 8427],
#        [1901, 8426],
#        [1900, 8425],
#        [1900, 8424],
#        [1899, 8423],
#        [1898, 8422],
#        [1897, 8421],
#        [1896, 8420],
#        [1895, 8419],
#        [1895, 8418],
#        [1894, 8417],
#        [1893, 8416],
#        [1892, 8415],
#        [1891, 8414],
#        [1891, 8413],
#        [1890, 8412],
#        [1889, 8411],
#        [1888, 8410],
#        [1887, 8409],
#        [1886, 8408],
#        [1886, 8407],
#        [1885, 8406],
#        [1884, 8405],
#        [1883, 8404],
#        [1882, 8403],
#        [1882, 8402],
#        [1881, 8401],
#        [1880, 8400],
#        [1879, 8399],
#        [1878, 8398],
#        [1877, 8397],
#        [1877, 8396]], dtype=int32)

# %%
conNum = 4
order = 10
plt.plot(contoursNONE[conNum][:,1], -contoursNONE[conNum][:,0])
plt.show()
# dst = cv2.ximgproc.fourierDescriptor(contoursRaw[conNum])
coeffs = elliptic_fourier_descriptors(contoursNONE[conNum], order=order, normalize=False)

f = plt.figure(figsize = (15,10))
pyefd.plot_efd(coeffs, locus=(contoursNONE[conNum][:,0].mean(), contoursNONE[conNum][:,1].mean()), image=None, contour=contoursNONE[conNum], n=300)

# %%
pyefd.plot_efd(coeffs, locus=(0, 0.0), image=None, contour=None, n=300)

# %%
dst = cv2.ximgproc.fourierDescriptor(contoursRaw[conNum])
len(dst)
# Out:
# 240

# %%
len(contoursNONE[conNum])
# Out:
# 227

# %%
dst2 = cv2.ximgproc.transformFD(dst, dfContour=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-c8e915a85356> in <module>
# ----> 1 dst2 = cv2.ximgproc.transformFD(dst, dfContour=True)
#
# TypeError: transformFD() missing required argument 't' (pos 2)

# %%
coeffs
# Out:
# array([[-5.55416508e+00, -4.04684412e+01, -4.25515397e+01,
#         -4.10813646e+00],
#        [-2.94079624e-02,  2.84963248e-02, -3.29012240e-02,
#          1.99249822e-02],
#        [ 3.46525274e+00,  3.55418298e+00, -4.36418466e+00,
#          3.67774843e-01],
#        [ 2.48499111e-02,  6.83695368e-02,  2.67322182e-02,
#          6.70101500e-02],
#        [-1.37905395e+00, -6.25172709e-01, -1.81078699e+00,
#         -9.05024409e-02],
#        [-2.38066688e-02,  2.34462818e-02, -2.60689018e-02,
#          2.27903994e-02],
#        [ 9.30863109e-01, -5.36661405e-02, -7.67121576e-01,
#          7.40330597e-03],
#        [ 1.69806901e-02,  2.01874850e-02,  1.73875405e-02,
#          1.87098934e-02],
#        [-3.94274741e-01,  2.78255839e-01, -5.64083366e-01,
#          1.18681901e-02],
#        [-1.40273112e-02,  2.63937034e-02, -1.48078548e-02,
#          2.75116617e-02]])

# %%
import pyefd
pyefd.plot_efd(coeffs, locus=(0.0, 0.0), image=None, contour=None, n=300)
