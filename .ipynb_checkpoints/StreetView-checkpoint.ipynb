# %% [markdown]
# # robolyst/streetview
# https://github.com/robolyst/streetview

# %%
import streetview
panoids = streetview.panoids(lat=-33.85693857571269, lon=151.2144895142714)

# %%
panoids = streetview.panoids(lat=39.2852837, lon=-74.5611446)
panoids

# %%
panoids
# Out:
# [{'panoid': 'pV6jtRc157XZtWpVIR-rtg',
#   'lat': -33.85693857571269,
#   'lon': 151.2144895142714,
#   'year': 2015,
#   'month': 12},
#  {'panoid': 'OH7ReEUauWGKYqUwff4csA',
#   'lat': -33.85701117876561,
#   'lon': 151.2144738599703},
#  {'panoid': 'aX3nhhCruYOr-i1vSef13Q',
#   'lat': -33.85686132734697,
#   'lon': 151.2145114182827},
#  {'panoid': 'Dnwib32GDUwR0ZEUpaRjwA',
#   'lat': -33.85721538674072,
#   'lon': 151.2144087097325},
#  {'panoid': 'QHQTTGU4c5FPNTRAef8NMQ',
#   'lat': -33.85728178709976,
#   'lon': 151.2143873393158},
#  {'panoid': 'T3Olav_5BHcO4mp26-p5uA',
#   'lat': -33.85679700784097,
#   'lon': 151.2145324891978},
#  {'panoid': 'UnQPs_i5Ve4PKBsiiKCGIg',
#   'lat': -33.85709265803713,
#   'lon': 151.2144511550587},
#  {'panoid': 'fyU-UFzcm46oYIHpfaqdEA',
#   'lat': -33.85715286182172,
#   'lon': 151.2144278142204},
#  {'panoid': '0Ih6zwlaAi7BJBPMyCGzIw',
#   'lat': -33.85656717348672,
#   'lon': 151.2145896255711},
#  {'panoid': 'D2hYV0KIE5z2DT3zKISPIw',
# ...

# %%
panoids = streetview.panoids(lat=39.2852837, lon=-74.5611446)
panoids
# Out:
# [{'panoid': 'D4XjmfLI7a2t12_-l5yjcw',
#   'lat': 39.28527412562956,
#   'lon': -74.56112735777008,
#   'year': 2013,
#   'month': 9},
#  {'panoid': 'y4i24UviKDv5ycmufm0Ctg',
#   'lat': 39.28528374553464,
#   'lon': -74.56114463076433,
#   'year': 2019,
#   'month': 10},
#  {'panoid': '9lJ3XrvvBnpDUOYLMYkVJg',
#   'lat': 39.28521831314583,
#   'lon': -74.56105960710761},
#  {'panoid': 'mErg8AriQ-2td5QpGlYzkQ',
#   'lat': 39.28534915034588,
#   'lon': -74.56123150380385},
#  {'panoid': '6apeNO9shNPnxDw6Z-xEIQ',
#   'lat': 39.28541370912505,
#   'lon': -74.56132171969935},
#  {'panoid': 'lLub1LZZO1scxd2mX4CGmQ',
#   'lat': 39.28515344884993,
#   'lon': -74.56097579709962},
#  {'panoid': 'yAuwsYPPzMFITOrg9tIHSQ',
#   'lat': 39.28573458729468,
#   'lon': -74.56074675498088},
#  {'panoid': 'uDpbO_4mrF1Yi2y_DCgnnQ',
#   'lat': 39.28549081776062,
#   'lon': -74.56155891382356},
#  {'panoid': '_vqojLVqvULn1RPM8D3RBA',
#   'lat': 39.28547286758905,
#   'lon': -74.56141733683255},
# ...

# %% [markdown]
# # clip local panoramas.

# %%
import pandas as pd
import glob
import os

from tqdm import tqdm

# %%
panoId_file = r'X:\My Drive\Research\StreetGraph\data\oceancity\property_address_panoIds.csv'
df = pd.read_csv(panoId_file, sep=',')
df
# Out:
#                                       address                 panoIds  \
# 0              1-3 ATLANTIC AVE Ocean City NJ  aLH8om-ax5boXJ-hXhFvaQ
# 1           1-3 E ATLANTIC BLVD Ocean City NJ  N2TakAa4EvhSCDIb44lEBw
# 2                 1-3 REVERE PL Ocean City NJ  n4aTTgHhJ2AkPbSg0X3MfA
# 3                1-3 SIMPSON RD Ocean City NJ  7pBBmj5k9GAh1o-n4ctSpQ
# 4                 1-3 W 12TH ST Ocean City NJ  0_Z25VniDxurxsixrPV1LA
# ...                                       ...                     ...
# 13071      W SIXTH ST & BAY AVE Ocean City NJ  eda5xLyxQsfgtWvQmxklCg
# 13072         WALNUT & FERNDALE Ocean City NJ                       0
# 13073               WATER FRONT Ocean City NJ  dXwSwu40mZ5tJgg8B-e2jA
# 13074        WATERVIEW & OXFORD Ocean City NJ  RGo71zkn6H1vysqcWM2bmA
# 13075  WEST OF BAY & SO OF 40TH Ocean City NJ  CLrbb6H376lIHrcVWuS0Hg
#
#               lon        lat
# 0      -74.560757  39.286135
# 1      -74.560354  39.286127
# 2      -74.578900  39.281543
# ...

# %%
folder = r'X:\My Drive\Research\StreetGraph\data\oceancity\panos'
existing_panos = glob.glob(os.path.join(folder, '*.jpg'))
existing_panos = [os.path.basename(p)[:-4] for p in existing_panos]
existing_panos
# Out:
# ['aUJOBTXEIB2qHXY4zNjS8g',
#  'jLUSogvCFnRkmiHX1M3Zhg',
#  'p6DWkwzAlgiaTEFShjINqg',
#  'AhgweDTYVhjFAxYh00_zxQ',
#  'Q4iIz3_eo9_zuzWp2R9s4Q',
#  '0-te95Ih1P_J9Fi2ySWYsA',
#  '9cEK4leONC9Yh6L2hkRKRQ',
#  'WYVMUOxDRUNWZHxi1QjN7w',
#  '0bwq7d5Ipw26Ht0b0c7vQw',
#  'e7OPBMXuS6r5jV49Zb50zg',
#  'dGQ3mnUkWg7kLVVyJYixYA',
#  'Uo_i55hd6yyfZWND4HW8CA',
#  'G3VfCTLgRDFIlplOg32uGw',
#  'E2E2AeCGNqGZwGWdD2angg',
#  'EhI3nBd__SbnHxkPFOQFqQ',
#  'VJH1P7tkwq5SIU1wYbdyZQ',
#  'aV3Kt85kviEszUsk-UzaNg',
#  '1IdEkKjH6COXx21Zx4RYeg',
#  'VwlFfIF_EgZuIokolBlhKg',
#  'TYiaWDADRso6C3FbEvFtYg',
#  'CG_iEMH_XeOFDlaMLrfc4Q',
#  'dXTyk8Re2VS7_uKwn_tGHA',
#  'hTTY5DCG7cwC408yQveRbw',
#  'EPaVXEINqkLWGxLSIYXYKA',
#  'Oc4Z_stPcI-8mdUMmZSUJQ',
#  'GINW95g5F6sr8Vn3vQxBpQ',
#  '7JNWu2eDLDGz8ro2XuOyxw',
#  'gxpJ8hOzQsjcB66lddMhzA',
#  '14YcmRIqLC-Ay5rpQkYFJw',
#  'pp8Bt5gK4nlLXDhi0TOMiQ',
#  'D6zBaGZFBCDD0y-0jzdexg',
#  'jTz0L8qtLGdVT98fF93sfA',
#  'NtVEZAmuCIYXOVklSHrTsw',
#  '-ZTmvxbPsw7FnSNc2ZO18w',
# ...

# %%
not_in_cnt = 0
# for idx, row in tqdm(df.iterrows()):
for idx, row in df.iterrows():
    panoId = row['panoIds']
    panoId = str(panoId)
    if panoId != '0':
        if panoId not in existing_panos:
            not_in_cnt +=1
            if len(panoId) < 40:
                print(row['lon'], row['lat'])
# Out:
# n4aTTgHhJ2AkPbSg0X3MfA
# eD6yAl7EAam1xa8Z6_5Amw
# No_0dIFyQgVQ15Ia4nsx8w
# _jzIkKNC_5TCCOXGBeodKQ
# u8K_tA16gxqk3NutP1O3PQ
# 9U-n20NiqzPenWx7HCFF8A
# JSGwy_t2GaqmUrbxDtbbxw
# cC3D4p-Lj3pUVQ03gdovQw
# 6-vpMZW_8DAvU03gsGjnrQ
# J_MMmqKBU7F0jGXqy3TOng
# BRRx44WzhvXLMtycSRdMSw
# iDi2zOxk_Ge6-cY59gtMJQ
# iDi2zOxk_Ge6-cY59gtMJQ
# iDi2zOxk_Ge6-cY59gtMJQ
# iDi2zOxk_Ge6-cY59gtMJQ
# iDi2zOxk_Ge6-cY59gtMJQ
# iDi2zOxk_Ge6-cY59gtMJQ
# iDi2zOxk_Ge6-cY59gtMJQ
# iDi2zOxk_Ge6-cY59gtMJQ
# BRRx44WzhvXLMtycSRdMSw
# oSG-a5UBsafP4St-uff-SQ
# kB32P9PKlLwWMlFtw1toww
# -nEFLYxXA-CsWgm53JUkwA
# -nEFLYxXA-CsWgm53JUkwA
# pL-hh8xx9Fmefd8Y2DtSMQ
# 1JoN1UTvzvWvJVB3CcsQpw
# z2aCPXbZB0MqemzCJocEEg
# yvXHYWsj2gyO6SS-RIFwGQ
# 9t0iWsLWlVfrDnAbYJgGYQ
# l3F2ZToQMmEp9yEy0ydb3Q
# oGLmuUlxIoWJAC6-2ODeHA
# 1JoN1UTvzvWvJVB3CcsQpw
# 4sGEXZQ1Aua6mUkuy_01og
# sZ0TYTF7DJCk9M6tiTVa0g
# MoAG4vnvB3vR3v46RUNT2g
# gIujuc8CQ4PnGHJiTRYhNg
# yvXHYWsj2gyO6SS-RIFwGQ
# -4nOGEQQAZFloypmAQgnRw
# -4nOGEQQAZFloypmAQgnRw
# -4nOGEQQAZFloypmAQgnRw
# ...

# %%
import base64
import zlib
import numpy as np
import struct
import matplotlib.pyplot as plt


def parse(b64_string):
    # fix the 'inccorrect padding' error. The length of the string needs to be divisible by 4.
    b64_string += "=" * ((4 - len(b64_string) % 4) % 4)
    # convert the URL safe format to regular format.
    data = b64_string.replace("-", "+").replace("_", "/")

    data = base64.b64decode(data)  # decode the string
    data = zlib.decompress(data)  # decompress the data
    return np.array([d for d in data])


def parseHeader(depthMap):
    return {
        "headerSize": depthMap[0],
        "numberOfPlanes": getUInt16(depthMap, 1),
        "width": getUInt16(depthMap, 3),
        "height": getUInt16(depthMap, 5),
        "offset": getUInt16(depthMap, 7),
    }


def get_bin(a):
    ba = bin(a)[2:]
    return "0" * (8 - len(ba)) + ba


def getUInt16(arr, ind):
    a = arr[ind]
    b = arr[ind + 1]
    return int(get_bin(b) + get_bin(a), 2)


def getFloat32(arr, ind):
    return bin_to_float("".join(get_bin(i) for i in arr[ind : ind + 4][::-1]))


def bin_to_float(binary):
    return struct.unpack("!f", struct.pack("!I", int(binary, 2)))[0]


def parsePlanes(header, depthMap):
    indices = []
    planes = []
    n = [0, 0, 0]

    for i in range(header["width"] * header["height"]):
        indices.append(depthMap[header["offset"] + i])

    for i in range(header["numberOfPlanes"]):
        byteOffset = header["offset"] + header["width"] * header["height"] + i * 4 * 4
        n = [0, 0, 0]
        n[0] = getFloat32(depthMap, byteOffset)
        n[1] = getFloat32(depthMap, byteOffset + 4)
        n[2] = getFloat32(depthMap, byteOffset + 8)
        d = getFloat32(depthMap, byteOffset + 12)
        planes.append({"n": n, "d": d})

    return {"planes": planes, "indices": indices}


def computeDepthMap(header, indices, planes):

    v = [0, 0, 0]
    w = header["width"]
    h = header["height"]

    depthMap = np.empty(w * h)

    sin_theta = np.empty(h)
    cos_theta = np.empty(h)
    sin_phi = np.empty(w)
    cos_phi = np.empty(w)

    for y in range(h):
        theta = (h - y - 0.5) / h * np.pi
        sin_theta[y] = np.sin(theta)
        cos_theta[y] = np.cos(theta)

    for x in range(w):
        phi = (w - x - 0.5) / w * 2 * np.pi + np.pi / 2
        sin_phi[x] = np.sin(phi)
        cos_phi[x] = np.cos(phi)

    for y in range(h):
        for x in range(w):
            planeIdx = indices[y * w + x]

            v[0] = sin_theta[y] * cos_phi[x]
            v[1] = sin_theta[y] * sin_phi[x]
            v[2] = cos_theta[y]

            if planeIdx > 0:
                plane = planes[planeIdx]
                t = np.abs(
                    plane["d"]
                    / (
                        v[0] * plane["n"][0]
                        + v[1] * plane["n"][1]
                        + v[2] * plane["n"][2]
                    )
                )
                depthMap[y * w + (w - x - 1)] = t
            else:
                depthMap[y * w + (w - x - 1)] = 9999999999999999999.0
    return {"width": w, "height": h, "depthMap": depthMap}


# see  https://stackoverflow.com/questions/56242758/python-equivalent-for-javascripts-dataview
# for bytes-parsing reference

# see https://github.com/proog128/GSVPanoDepth.js/blob/master/src/GSVPanoDepth.js
# for overall processing reference

# Base64 string from request to:
# https://maps.google.com/cbk?output=xml&ll=45.508457,-73.532738&dm=1
# edit long and lat
#s = "eJzt2gt0FNUdx_FsQtgEFJIQiAlvQglBILzktTOZ2YitloKKD6qAFjy2KD5ABTlqMxUsqICcVqqC1VoUqS34TkMhydjaorYCStXSKkeEihQoICpUFOzuJruZO4_dmdmZe2fY3_cc4RCS-L_z-c_sguaNy8rKzgrkZSGEEEIIIYQQQgghhBBCCCGEEEIIIYQQQgghhBBCCCGEEEIIIYQQQgghhBBCCCGEEEIIIYQQQgghhBBCCCGEEEIIIYQQQgghhBBCCCGEEEIIIYQQQgghh
im = depthMap["depthMap"]
im[np.where(im == max(im))[0]] = 255
if min(im) < 0:
    im[np.where(im < 0)[0]] = 0
im = im.reshape((depthMap["height"], depthMap["width"])).astype(int)
# display image
plt.imshow(im)
plt.show()

# %%
from math import *
import scipy.ndimage
from scipy import interpolate

dempth_image = np.array(depthMap['depthMap']).reshape(256, 512)

gridx = np.linspace(-pi, pi, 512)
gridy = np.linspace(-pi/2, pi/2, 256)
gridx, gridy = np.meshgrid(gridx, gridy)
#dempth_image = depthMap
print("shapes: gridx, gridy", gridx.shape, gridy.shape, dempth_image.shape)
print("types: gridx, dempth_image", type(gridx), type(dempth_image))
interp = interpolate.interp2d(gridx, gridy, dempth_image, kind='linear')

# %%
print(depthMap["depthMap"][512*100:512*100+512])
# Out:
# [255.         255.         255.         255.         255.
#  255.         255.         255.         255.         255.
#  255.         255.         255.         255.         255.
#  255.         255.         255.         255.         255.
#  255.         255.         255.         255.         255.
#  255.         255.         255.         255.         255.
#  255.         255.         255.          22.19364724  20.58570528
#   19.65285682  18.96961894  18.33486834  17.74372206  17.19193237
#   16.67578674  16.1920262   15.73777812  15.31050066  14.90793652
#   14.52807421  14.16911554  13.82944809  13.50762184  13.20232926
#   12.91238826  12.6367275   12.37437378  12.12444101  11.94559539
#   11.86035578  11.77807448  11.69866601  11.62204921  11.54814691
#   11.4768858   11.40819621  11.3420119   11.27826993  11.21691047
#   11.15787667  11.1011145   11.04657264  10.99420236  10.94395738
#   10.89579379  10.84966992  10.8055463   10.76338552  10.72315216
# ...

# %%
data["planes"]
# Out:
# [{'n': [0.0, 0.0, 0.0], 'd': 0.0},
#  {'n': [0.00278832227922976, 0.012693333439528942, -0.9999155402183533],
#   'd': 2.4096500873565674},
#  {'n': [-3.5305974367894543e-17, 0.02996334619820118, -0.999550998210907],
#   'd': 2.4099462032318115},
#  {'n': [-0.0008027480216696858, 0.00606440007686615, -0.9999812841415405],
#   'd': 2.501049757003784},
#  {'n': [0.9340373277664185, -0.35685569047927856, 0.015111044980585575],
#   'd': 9.743698120117188},
#  {'n': [0.003294638590887189, 0.0023731396067887545, -0.999991774559021],
#   'd': 2.563364267349243},
#  {'n': [0.00540130352601409, 0.01577465794980526, -0.9998610019683838],
#   'd': 2.4413869380950928},
#  {'n': [0.6408694982528687, -0.7676185965538025, -0.006926527246832848],
#   'd': 7.397400856018066},
#  {'n': [0.9924386143684387, 0.11835674196481705, 0.032515354454517365],
#   'd': 5.988276958465576},
#  {'n': [3.8241400133828823e-17, 0.1002279743552208, -0.9949644804000854],
#   'd': 2.4036524295806885},
# ...

# %%
import requests
import os
import PIL
import numpy
import json
def getPanoIdfrmLonlat2(lon, lat):
    url = f'http://maps.google.com/cbk?output=json&ll={lat},{lon}'
    print(url)
    r = requests.get(url)
    data = r.json()
    if 'Location' in data:
        return(data['Location']['panoId'], data['Location']['original_lng'], data['Location']['original_lat'])
    else:
        return 0, 0, 0
    
def getDepthmapfromText(str_dm, saved_path):
    try:
        depthMapData = parse(str_dm)
        # parse first bytes to describe data
        header = parseHeader(depthMapData)
        # parse bytes into planes of float values
        data = parsePlanes(header, depthMapData)
        # compute position and values of pixels
        depthMap = computeDepthMap(header, data["indices"], data["planes"])
        im = depthMap["depthMap"]
        #print(im)
        #img = PIL.Image.fromarray(numpy.float(im).reshape((depthMap["height"], depthMap["width"])))
        img = im.reshape((depthMap["height"], depthMap["width"]))
    #         print(img)
        img = PIL.Image.fromarray(img)
    #         ma = numpy.array(img)
    #         print(ma)
        #img.save(mapname, compression="tiff_deflate")
        img.save(mapname)
    except Exception as e:
        print("Error in getDepthmaprmText():", e)
        
        
def getJsonDepthmapfrmLonlat(lon, lat, dm=1, saved_path='', prefix='', suffix=''):
    prefix = str(prefix)
    suffix = str(suffix)
    if prefix != "":
        prefix += '_'
    if suffix != "":
        suffix = '_' + suffix
    url = f'http://maps.google.com/cbk?output=json&ll={lat},{lon}&dm={dm}'
    #print(url)
    try: 
        r = requests.get(url)
        jdata = r.json()
        str_dm = jdata['model']['depth_map']
        #del jdata['model']
        
        mapname = os.path.join(saved_path, prefix + jdata['Location']['original_lng'] + '_' + jdata['Location']['original_lat'] + '_' + jdata['Location']['panoId'] + suffix + '.tif')
 
        #print(img)
        # process float 1D array into int 2D array with 255 values
        
#         im[np.where(im == max(im))[0]] = 255
#         if min(im) < 0:
#             im[np.where(im < 0)[0]] = 0
#         im = im.reshape((depthMap["height"], depthMap["width"])).astype(int)
        # display image
#         plt.imshow(im)
#         plt.show()
        #return(data['Location']['panoId'], data['Location']['original_lng'], data['Location']['original_lat'])

        #mapname = os.path.join(saved_path, (prefix + data['Location']['original_lng'] + '_' + data['Location']['original_lat'] + '_' + data['Location']['panoId'] + suffix + '.jpg'))
#         img = PIL.Image.fromarray(numpy.uint8(im))
        
#         img.save(mapname)
       # print(data['model'])
        with open(mapname[:-5] + '.json', 'w') as f:
            json.dump(jdata, f)
         
    except Exception as e:
        print("Error in getPanoIdDepthmapfrmLonlat():", str(e))
        print(url)

#getPanoIdfrmLonlat2(-74.3168591, 40.7984031)
#getPanoIdfrmLonlat2(-74.0, 40.0)
    
getJsonDepthmapfrmLonlat(-74.317149454999935, 40.798423060000061, dm=1, saved_path=r'J:\Sidewalk\google_street_view\Essex_detpthmap')

# %%
import pandas as pd
df = pd.read_csv(r'K:\Research\NJTPA\Essex_10m_points.csv')

# %%
saved_path = r'J:\Sidewalk\google_street_view\Essex_detpthmap'
df = df.fillna(0)
df = df[11235:]
for idx, row in df.iterrows():
    try:
        getJsonDepthmapfrmLonlat(row.lon, row.lat, saved_path = saved_path, prefix=int(row.id))
        if idx % 1000 == 0:
            print("Current row:", idx)
    except Exception as e:
        print("Error in row: ", idx)
        continue
# Out:
# Error in getPanoIdDepthmapfrmLonlat(): 'model'
# http://maps.google.com/cbk?output=json&ll=40.827385449000076,-74.22579825499997&dm=1
# Error in getPanoIdDepthmapfrmLonlat(): 'model'
# http://maps.google.com/cbk?output=json&ll=40.82737623500003,-74.22589883499995&dm=1
# Error in getPanoIdDepthmapfrmLonlat(): 'model'
# http://maps.google.com/cbk?output=json&ll=40.82736545300003,-74.22601654099998&dm=1
# Error in getPanoIdDepthmapfrmLonlat(): 'model'
# http://maps.google.com/cbk?output=json&ll=40.741431430000034,-74.17845522399993&dm=1
# Error in getPanoIdDepthmapfrmLonlat(): 'model'
# http://maps.google.com/cbk?output=json&ll=40.74246659800008,-74.17784625499998&dm=1
# Error in getPanoIdDepthmapfrmLonlat(): 'model'
# http://maps.google.com/cbk?output=json&ll=40.742171289000055,-74.17802003299995&dm=1
# Error in getPanoIdDepthmapfrmLonlat(): 'model'
# http://maps.google.com/cbk?output=json&ll=40.742089089000046,-74.17806840599997&dm=1
# Error in getPanoIdDepthmapfrmLonlat(): 'model'
# ...

# %%
img2 = PIL.Image.open(r'J:\Sidewalk\google_street_view\Essex_detpthmap\-74.317158_40.798426_z9isVpiwFbvDhNjlc_O1dA.tif')
print(numpy.array(img2))

# %%
import glob
import os
all_files = glob.glob(r'J:\Sidewalk\google_street_view\Essex_detpthmap\*.json')

# %%
for file in all_files:
    os.rename(file, file.replace(".0_-74.", '-74.'))

# %%
all_files[0].replace(".0_-74.", '-74.')
# Out:
# 'J:\\Sidewalk\\google_street_view\\Essex_detpthmap\\1-74.317158_40.798426_z9isVpiwFbvDhNjlc_O1dA.json'

# %%
all_files[0]
# Out:
# 'J:\\Sidewalk\\google_street_view\\Essex_detpthmap\\1.0_-74.317158_40.798426_z9isVpiwFbvDhNjlc_O1dA.json'

# %%
s = r'eJzt2Ht4U_Udx_Fy7YWWQmlp6SWUu9AbFItIzknOCVKgIGJRUYHCZGwTH3RMrFpKj9RKEQQFVHi4WBFlKOOmWKVN8kN04g0fQeYUxQkydLSKe9wFYeKSNElPmpNL0ySfNHxf_ygpT5t83t-EB6KmRkR0jOgQFUEIIYQQQgghhBBCCCGEEEIIIYQQQgghhBBCCCGEEEIIIYQQQgghhBBCCCGEEEIIIYQQQgghhBBCCCGEEEIIIYQQQgghhBBCCCGEEEIIIYQQQgghhBBCCCGEEEIIIYQQQgghhBBCCCGEEEIIIYQQQgghhBBCCCGEEEIIIYQQQq5snTqhnwEJvk4uoJ8XCTBX4ekOwpyX4ekMwo9P6ekK2qm21qYbaHcCk5yOoB0IVvoA3kC-_79lS10VaDQay38D_9MDI-jlrSIjI_31Erpb-L2_LHKUSRcZhf52_n4aAYRqb-0f6Ycb6G4XqP5RVl0UOfdvH3eATC_v39YbCHD_qGbK_Z0_EEL_DtDpLSId-fpaAto_KsoP_UPrCtDZ7SKd-fJ6Atl_MPUPHIX-kZFcq1-PQv_eVkkmbZmK-gcS9YdAZ7fzT__u1L910NntqD8EOrsd9Q-cHg4cvoTObuepv3d_HaD-zlJTw6O_hYfXqtC_d3j1zzDJ9fL3plop9B9qFhHq_WWvxfpIZqbbVxzG_RPMMixyvTyAsOyf6e4E3PRPar_9E-yofxD7p1jYf9l--6c697cdADq7jWL-1vXv27fvaFl_28Ot_fhPSdGNGDEixc7-hfbXf_IV0T8729K-L_VvSbn_MJPCQlP9wsJhw9DdbdrUv29fhf4DLAYNGhTjSkSE0k20
q0zPZzz_O-GWp97n3vr4BuMd68vYbbP0mle33Mxr47O5_G0S-2bzSKHrrnhWuXMay-2YbLhYc7P4YeH1-imb4vknTPeTnXJKu7cHx55dn6NN_c3r-ofWLhJn3DdU3_XCPD7jKYltz35EO_BkZf3FmSv1l_8tsZkP3yVERB7hvzr8X27rhgr2wssfCc-8NI1d_DBem7XrG_2lQoO4cti7XLVuBfftaYmtP3yjUFb2GXf-6cv8nMYlbBkXJ_68YLfm_j2_Z4N37RjzflK6btYT6_jPdDn8iVSJHch_V_h4_mo-p-gmQ_doiY3j8rX1xWvqapdV8RtLJXbh5xWaafpqw9fHntf0OLxQa1izSTj9QZH2XvUbXHZGunbA_hzdj9WpfG3tIk3MvAcYv7pSHH7hBvZhRpL2xgt_0x9asUGsNb3XSi6NNJat6cj68xN1VWmfcy9t6cS_8rbE0nfcIby-8x3O-GgJX7lSYjf8up_2_xf-xcA'

# %%
# decode string + decompress zip
depthMapData = parse(s)
# parse first bytes to describe data
header = parseHeader(depthMapData)
# parse bytes into planes of float values
data = parsePlanes(header, depthMapData)
# compute position and values of pixels
depthMap = computeDepthMap(header, data["indices"], data["planes"])
# process float 1D array into int 2D array with 255 values
im = depthMap["depthMap"]
im[np.where(im == max(im))[0]] = 255
if min(im) < 0:
    im[np.where(im < 0)[0]] = 0
im = im.reshape((depthMap["height"], depthMap["width"])).astype(int)
# display image
plt.imshow(im)
plt.show()

# %%
import glob
import os
all_files = glob.glob(r'J:\Workspace\all\*.*')

# %%
cnt = 0
for file in all_files:
    new_name = file.replace("DOM2015", '')
    os.rename(file, new_name)
    cnt += 1
    if cnt % 100 == 0:
        print(cnt)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# ...

# %% [markdown]
# # Project Lon/lat to Web Mecator

# %%
import pandas as pd
import numpy as np
#import netCDF4
#from netCDF4 import Dataset
import os
from pyproj import Proj
from datetime import datetime
import datetime
import sys
import time
#from netCDF4 import num2date, date2num
#import h5py
import IPython
import time
import timeit
from IPython.display import display, HTML
import os
import glob
import sys
import sys
from pygeotile.tile import Tile
from pygeotile.point import Point
#import tarfile
from six.moves import urllib
import matplotlib.pyplot as plt
#from shapely.geometry import Polygon
#import cartopy.crs as ccrs
#import cartopy.io.img_tiles as cimgt
import networkx as ntx
from scipy import ndimage as nd
from skimage import io

# from bokeh.io import output_file, output_notebook, show
# from bokeh.models import (
#   GMapPlot, GMapOptions, ColumnDataSource, Circle, LogColorMapper, BasicTicker, ColorBar,
#     DataRange1d, PanTool, WheelZoomTool, BoxSelectTool
# )
# from bokeh.models.mappers import ColorMapper, LinearColorMapper
# from bokeh.palettes import Viridis5


# Put your path here
#Quadtree_level = 21
#csv_path = r'D:\Buston\Boston2017_18.csv'
UL = (-71.163736,   42.458042 )
BR = (-71.006377,   42.278300)

spatial_interval = 1000  # meter
time_interval = 60*24     # miniute
mid_point = ((UL[0] + BR[0])/2, (UL[1]+ BR[1])/2)
UTM_zone = int((mid_point[0])/6) + 30
if mid_point[0] > 0:   # needs to be verified.
    UTM_zone +=1

    
from pyproj import Proj, transform
print(transform(Proj(init='epsg:4326'), Proj(init='epsg:3857'), -0.1285907, 51.50809))  # longitude first, latitude second.
# output (meters east of 0, meters north of 0): (-14314.651244750548, 6711665.883938471)
# Out:
# (-14314.651244750603, 6711665.883938471)

# %%
from pyproj import Proj, transform
print(transform(Proj(init='epsg:4326'), Proj(init='epsg:3857'), -0.1285907, 51.50809))  # longitude first, latitude second.
# output (meters east of 0, meters north of 0): (-14314.651244750548, 6711665.883938471)
# Out:
# (-14314.651244750603, 6711665.883938471)

# %%
point = (63, 3,4, 4)
print("%s, %s, %s, %s" % point)
# Out:
# 63, 3, 4, 4

# %%
import numpy as np
pointcloud_class= np.array([[-8.26092134e+06,4.98177244e+06,1.99186850e+01,0.00000000e+00,
   2.00000000e+00], [-8.26092134e+06,4.98177244e+06,2.99186850e+01,0.00000000e+00,
   2.00000000e+00], [-8.26092134e+06,  4.98177244e+06,  3.99186850e+01,  0.00000000e+00,
   2.00000000e+00]])

# %%
distance_min = 0
#pointcloud_class[pointcloud_class[3,:] > distance_min]
pointcloud_class.any(pointcloud_class[:,2] > 1, pointcloud_class[:,2] < 20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-e6d263d10801> in <module>
#       1 distance_min = 0
#       2 #pointcloud_class[pointcloud_class[3,:] > distance_min]
# ----> 3 pointcloud_class.any(pointcloud_class[:,2] > 1, pointcloud_class[:,2] < 20)
#
# d:\Anaconda3\lib\site-packages\numpy\core\_methods.py in _any(a, axis, dtype, out, keepdims)
#      41
#      42 def _any(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 43     return umr_any(a, axis, dtype, out, keepdims)
#      44
#      45 def _all(a, axis=None, dtype=None, out=None, keepdims=False):
#
# TypeError: data type not understood

# %%
import numpy as np 

x = np.random.randn(20, 3) 
x_new = x[np.sum(x, axis=1) > .5] 

def myfunc(row): 
    return sum(row) > .5 

bool_arr = np.array([myfunc(row) for row in x]) 
x_new = x[bool_arr] 

x = np.random.randn(5000, 200)
# Out:
# 3 ms ± 70.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit x[np.array([myfunc(row) for row in x])] 
# 1 loops, best of 3: 217 ms per loop
# Out:
# 138 ms ± 841 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit x[np.sum(x, axis=1) > .5] 
# 100 loops, best of 3: 5.71 ms per loop
# Out:
# 3.13 ms ± 100 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
worldfile=[0.1, 0, 0, -0.1, -8260665.108798629, 4981984.695031309]

# %%
print('\n'.join(worldfile))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-e491a3e5872e> in <module>
# ----> 1 print('\n'.join(worldfile))
#
# TypeError: sequence item 0: expected str instance, float found

# %%
import json
import glob
import os
all_files = glob.glob(r'O:\OneDrive_NJIT\OneDrive - NJIT\Research\sidewalk\Essex_test\landcover\+pitch_of_thumb\*.json')

# %%
len(all_files)
# Out:
# 316

# %%
panoid_attrs = []
for file in all_files:
    try:
    
        with open(file, 'r') as f:
            jdata = json.load(f)    
            #print('panoid: ', panoid)  # ok
        pano_yaw_deg = jdata['Projection']['pano_yaw_deg']
        tilt_yaw_deg = jdata['Projection']['tilt_yaw_deg']
        tilt_pitch_deg = jdata['Projection']['tilt_pitch_deg']
        panoId = jdata['Location']['panoId']
        original_lat = jdata['Location']['original_lat']
        original_lng = jdata['Location']['original_lng']
        elevation_wgs84_m = jdata['Location']['elevation_wgs84_m']
#         best_view_direction_deg = jdata['Location']['best_view_direction_deg']
        elevation_egm96_m = jdata['Location']['elevation_egm96_m']
        description = jdata['Location']['description']
        panoid_attrs.append((panoId, description, original_lat, original_lng, pano_yaw_deg, tilt_yaw_deg, tilt_pitch_deg,elevation_wgs84_m, elevation_egm96_m))
    except Exception as e:
        print(e)
        continue

# %%
with open(r'O:\OneDrive_NJIT\OneDrive - NJIT\Research\sidewalk\Essex_test\json_all.csv', 'w') as f:
    f.writelines('panoId,description, original_lat, original_lng, pano_yaw_deg, tilt_yaw_deg, tilt_pitch_deg,elevation_wgs84_m, elevation_egm96_m')
    f.write('\n')      
    for line in panoid_attrs:
        #print(line)
        s = ','.join([str(x) for x in line])
        f.writelines(s + '\n')

# %%
class myClass(object):
    i = 3
print(myClass.i)  # 3
# Out:
# 3

# %%
 
myClass.i = 10
print(myClass.i)  # 3
# Out:
# 10

# %%
myc = myClass()
myc.i = 4
print(myc.i)
# Out:
# 4

# %%
print(myClass.i)
# Out:
# 8

# %%
myc2 =  myClass()
print(myc2.i)
# Out:
# 8

# %%
Class myClass():
    i = 3
print(myClass.i)  # 3
# Out:
#   File "<ipython-input-65-f50a3881abd9>", line 1
#     Class myClass():
#                 ^
# SyntaxError: invalid syntax

# %%
class myClass(object):
    i = 3
print(myClass.i)  # 3

myc = myClass()
myc.i = 20

print(myc.i)  # 20, the i in the instance of myc can be changed.
print(myClass.i)  # 3, the i in myClass is not changed.

myClass.i = 30
print(myClass.i)  # 30, the i in myClass is changed.
print(myc.i)  # 20, the i in the instance of myc can be changed.

myc2 = myClass()
print(myc2.i)  # 30
# Out:
# 3
# 20
# 3
# 30
# 20
# 30

# %%
class Computer():
    cpu = 'i7'
    def getCPU(self):
        print(self.cpu)
        
    def setCPU(self, cpu_name):
        self.cpu = cpu_name

# %%
computer = Computer()
computer.getCPU()
computer.setCPU('AMD')
computer.getCPU()
# Out:
# i7
# AMD

# %%
class Calculator():
    def add(self, a, b):
        return a + b

calculator = Calculator()    
print(calculator.add(3, 4))
# Out:
# 7

# %%
# importing libraries 
import time 
import math 
  
# decorator to calculate duration 
# taken by any function. 
def calculate_time(func): 
      
    # added arguments inside the inner1, 
    # if function takes any arguments, 
    # can be added like this. 
    def inner1(*args, **kwargs): 
  
        # storing time before function execution 
        begin = time.time() 
          
        func(*args, **kwargs) 
  
        # storing time after function execution 
        end = time.time() 
        print("Total time taken in : ", func.__name__, end - begin) 
  
    return inner1 
  
  
  
# this can be added to any function present, 
# in this case to calculate a factorial 
@calculate_time
def factorial(num): 
  
    # sleep 2 seconds because it takes very less time 
    # so that you can see the actual difference 
    time.sleep(2) 
    print(math.factorial(num)) 
  
# calling the function. 
factorial(10)
# Out:
# 3628800
# Total time taken in :  factorial 2.0009372234344482
