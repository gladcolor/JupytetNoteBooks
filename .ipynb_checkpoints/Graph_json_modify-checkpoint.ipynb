# %%
import json
import glob
import os
import geopandas as gpd
from natsort import natsorted
from pprint import pprint
from shapely.geometry import Point, Polygon
# !dir
# Out:
# Can't load requested DLL: C:\Program Files\GDAL\gdalplugins\gdal_KEA.dll
# 127: The specified procedure could not be found.
#
# Can't load requested DLL: C:\Program Files\GDAL\gdalplugins\gdal_KEA.dll
# 127: The specified procedure could not be found.
#
# Can't load requested DLL: C:\Program Files\GDAL\gdalplugins\ogr_MSSQLSpatial.dll
# 126: The specified module could not be found.
#
# Can't load requested DLL: C:\Program Files\GDAL\gdalplugins\ogr_MSSQLSpatial.dll
# 126: The specified module could not be found.
#
# Can't load requested DLL: C:\Program Files\GDAL\gdalplugins\gdal_KEA.dll
# 127: The specified procedure could not be found.
#
# Can't load requested DLL: C:\Program Files\GDAL\gdalplugins\gdal_KEA.dll
# 127: The specified procedure could not be found.
#
# Can't load requested DLL: C:\Program Files\GDAL\gdalplugins\ogr_MSSQLSpatial.dll
# 126: The specified module could not be found.
#
# Can't load requested DLL: C:\Program Files\GDAL\gdalplugins\ogr_MSSQLSpatial.dll
# 126: The specified module could not be found.
#  Volume in drive L is SSD
#  Volume Serial Number is F8D5-37FF
#
#  Directory of L:\Research\Jupyter_notebooks
#
# 10/07/2020  09:41 AM    <DIR>          .
# 10/07/2020  09:41 AM    <DIR>          ..
# 10/07/2020  09:41 AM    <DIR>          .idea
# 10/07/2020  09:41 AM    <DIR>          .ipynb_checkpoints
# 10/07/2020  09:29 AM           634,379 .~Graph_json_modify.ipynb
# 12/31/2019  10:59 PM         1,067,196 .~UNet_PyTorch_sidewalk_aerial-DVRPC2.ipynb
# 10/05/2020  08:49 PM         6,462,109 3.visualize_custom_SGDet.ipynb
# 07/05/2020  10:07 AM             3,915 acc.txt
# 02/23/2020  12:14 AM               101 address of the file location
# 12/25/2019  12:29 PM            53,247 ade20k_example.jpg
# 10/07/2020  09:41 AM    <DIR>          Auto-PyTorch
# 05/02/2020  12:12 PM               569 automl.7z
# 04/26/2020  10:27 PM               862 automl.py
# 05/02/2020  07:20 PM             6,623 Auto_pytorch_test.ipynb
# 02/04/2020  11:43 PM             3,663 basic_example_writer_sgskip.ipynb
# 07/05/2020  10:02 AM                27 best_acc.txt
# 04/17/2020  05:31 PM           249,406 biking.jpg
# 04/18/2020  01:42 PM           145,079 bok-topics_11.html
# 08/11/2020  11:44 PM             1,000 caffe_test.ipynb
# 07/04/2020  10:38 PM        44,786,668 cifar_resnet.pth
# 08/13/2020  09:04 AM           287,952 COCO_drawing.ipynb
# 07/19/2020  08:37 AM            20,047 Computinal_land_scape.ipynb
# 03/26/2020  11:15 AM            16,073 Copy of Maryland data into labels.ipynb
# 08/13/2020  10:47 AM           107,653 Covid19_data.ipynb
# 08/13/2020  09:01 AM            20,992 Crime_dallas.ipynb
# 04/25/2020  04:12 PM           481,575 CS610.ipynb
# 05/12/2020  09:24 AM         4,806,698 CS786_to_Metis.ipynb
# 10/14/2019  11:19 PM           820,852 CSV2HDF_cleaned.ipynb
# 07/05/2020  10:22 PM           289,532 DaC_test.ipynb
# 08/07/2020  09:03 AM            29,525 Pytorch_test.ipynb
# 06/22/2020  09:47 AM        52,450,301 PyTorch_VertNet01.ipynb
# 01/10/2020  10:22 AM                36 README.md
# 03/20/2020  04:21 PM           146,114 Remote_sensing_YOLACT.ipynb
# 11/09/2019  10:55 PM         3,000,054 rendered_image_-20_-90.bmp
# 11/12/2019  01:09 AM           787,510 rendered_image_0_-90.bmp
# 11/09/2019  10:53 PM         3,000,054 rendered_image_0_0.bmp
# 11/12/2019  01:08 AM           787,510 rendered_image_0_90.bmp
# 11/09/2019  10:55 PM         3,000,054 rendered_image_20_-90.bmp
# 11/09/2019  10:54 PM         3,000,054 rendered_image_20_0.bmp
# 08/30/2020  01:37 PM        16,072,469 Resilience.ipynb
# 07/06/2020  04:19 PM         5,614,184 ResNet3.ipynb
# 07/05/2020  05:13 PM         5,520,999 ResNet_Huan.ipynb
# 05/04/2020  10:30 AM         3,687,722 shap.ipynb
# 05/02/2020  11:55 AM         1,028,590 shap_kim.ipynb
# 05/02/2020  11:10 AM           284,180 SHAP_test.ipynb
# 05/07/2020  11:51 AM            16,502 SQLAlchemy_learning.ipynb
# 09/15/2020  05:11 PM           249,894 StreetView.ipynb
# 09/15/2020  08:43 AM         4,078,080 StreetViewTools.ipynb
# 01/16/2020  09:28 PM                 0 temp.bmp
# 01/16/2020  09:29 PM                 0 temp.jpg
# 01/16/2020  09:57 PM             2,442 temp.png
# 01/16/2020  09:30 PM             1,328 temp.png.aux.xml
# 01/16/2020  09:30 PM                 5 temp.png.vat.cpg
# 01/16/2020  09:30 PM               158 temp.png.vat.dbf
# 01/16/2020  09:28 PM           213,146 temp.tif
# 01/16/2020  12:01 AM            12,288 test.db
# 12/12/2019  11:03 AM            25,404 test.log
# 09/11/2020  09:26 PM           735,938 Test_codes.ipynb
# 02/04/2020  11:56 PM         2,017,753 TreeRootDetection.mp4

# %%
image_dir = r'L:\Datasets\ocean_city\processed_json'
extension =  'json'
files = glob.glob(os.path.join(image_dir, "*." + extension))
files = natsorted(files)
files
# Out:
# ['L:\\Datasets\\ocean_city\\processed_json\\1_aLH8om-ax5boXJ-hXhFvaQ_123.73.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\2_N2TakAa4EvhSCDIb44lEBw_83.71.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\3_n4aTTgHhJ2AkPbSg0X3MfA_11.99.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\4_7pBBmj5k9GAh1o-n4ctSpQ_56.94.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\5_0_Z25VniDxurxsixrPV1LA_33.93.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\6_WHxaTCBPZ8v_L8S9Nr24fA_43.17.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\8_M3I2qNQeBB2MFg3IHuCbig_104.0.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\9_as2lf1LPPhGI1D5DEQtDyA_55.07.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\10_piJ3-HBctCPJ9qejZZesEQ_121.73.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\11_eD6yAl7EAam1xa8Z6_5Amw_31.49.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\13_xixwgkh4GQ9uyj7DHwqcgw_54.73.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\14_mvxG0Y8r3Yzv-4e1_6esjQ_115.1.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\15_IU40Fjvi2newL6AnPrtlvQ_128.5.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\16_r2WkUL9GBcc6Sls1nruS-g_141.37.json',
#  'L:\\Datasets\\ocean_city\\processed_json\
json',
#  'L:\\Datasets\\ocean_city\\processed_json\\193_KgkmC03j17cgMHoHu5feRA_127.56.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\224_bvX_MAJuwBH8V3vF-0EFwg_348.18.json',
#  'L:\\Datasets\\ocean_city\\processed_json\\225_QxTASb5D1FbvV5Y3jdd8Zg_42.75.json']

# %%
def isDuplicateID(id_list):
    id_set = set(id_list)
    if len(id_list) == len(id_set):
        return False
    else:
        return True
isDuplicateID(["2", None, None])
# Out:
# True

# %%
def getShape_all_id(shapes):
    
    try:
        all_ids = []
        for shape in shapes:
            
            all_ids.append(shape.get('object_id', None))
                          
    except Exception as e:
        print(e)
        return None
#     print(len(all_ids))
    return all_ids
                          
def renewShapeId(shapes):
    for idx, shape in enumerate(shapes):
        shape["object_id"] = idx + 1

# %%
def twoPoints_to_polygon(p1: (float, float), p2: (float, float))->Polygon:
#     print(p1, p2)
    p3 = (p1[0], p2[1])
    p4 = (p2[0], p1[1])
    return Polygon([p1, p3, p2, p4, p1])

twoPoints_to_polygon((2076, 2214), (2163, 2431))

# %%
def createPolygons(shapes):
    polygons = []
    for shape in shapes:
        shape_type = shape["shape_type"]
        points = shape["points"]
#         print("points:", points)
        if len(points) == 2:
            polygon = twoPoints_to_polygon(points[0], points[1])
        elif len(points) > 2:
            polygon = Polygon(points + [points[0]])
            
        polygons.append(polygon)
    return polygons

def getGeoSeries(shapes):
    polygons = createPolygons(shapes)
    return gpd.GeoSeries(polygons)

# %%
files[-4]
# Out:
# 'L:\\Datasets\\ocean_city\\processed_json\\192_SEkj2oHWNtV5D7CMddAKlA_131.13.json'

# %%
f = open(files[-4], 'r')
jdata = json.load(f)
f.close() 
shapes = jdata["shapes"]

g = getGeoSeries(shapes)
len(g)
# Out:
# 61

# %% [markdown]
# # Relationship

# %% [markdown]
# ## utilities

# %%
def fill_relation(subject, predicate, object_):        
    relation = {}

    relation["subject"] = {}
    relation["subject"]["name"] = subject["label"]
    relation["subject"]["object_id"] = subject["object_id"]

    relation["predicate"] = predicate

    relation["object"] = {}
    relation["object"]["name"] = object_["label"]
    relation["object"]["object_id"] = object_["object_id"]
    
    return relation

# %% [markdown]
# ##  House Components

# %%
def isHouseComponents(thing:str)->bool:
    house_components_list = ["deck", "garage", "door", "window", "dormer", "vent", "balcony", "basement", "chimney", 
                             "column", "cupola", "facade", "foundation", "gutter", "knewwwall", "overhang-floor", 
                            "patio", "porch", "porch-skirt", "roof", "sidelight", "toplight", "stair", "step", "storey", "terrace", 
                             "vent-turet", "wall"]
    if thing in house_components_list:
        return True
    else:
        return False
    
def init_house_relation(idx, shapes, geo_series):
    shape = shapes[idx]
    relation_list = []
    polygon = geo_series[idx]
    distances = geo_series.distance(polygon)
#             print(distances)

    insides_idx = distances[distances < 1].index
#     print("type(insides):", type(list(insides_idx)))
#             print(insides_idx)
    for idx2 in insides_idx:
        thing = shapes[idx2]["label"]
        if isHouseComponents(thing):  
            predicate = "component_of"
            relation = fill_relation(shapes[idx2], predicate, shape)           
            relation_list.append(relation)
            
    isPrint = False
#     isPrint = True
    if isPrint:        
        print("Component of house: ", shape["object_id"])       
        [print(r['subject']["name"], r['subject']['object_id']) for r in relation_list]            
        print("")   
    
    print("Found {} relationships for {} - {}\n".format(len(relation_list), shapes[idx]["label"], shapes[idx]["object_id"]))

    return relation_list

# %% [markdown]
# ## step relation

# %%
def init_step_relation(idx, shapes, geo_series):
    
    shape = shapes[idx]
    relation_list = []
    polygon = geo_series[idx]
    distances = geo_series.distance(polygon)
#     print(distances)
    
    bounds = geo_series.bounds
    widths = bounds.maxx - bounds.minx
    heights = bounds.maxy - bounds.miny
# #     print(widths)
#     print(heights)
    
    near_ratio = 0.3 # assume that step can connect the object within near_ratio * height.
    
    step_height = heights[idx]
    near_idx = distances[distances < near_ratio * step_height].index
#     print("type(insides):", type((near_idx)))
#     print("near_idx:", near_idx)

    for idx2 in near_idx:
        thing = shapes[idx2]["label"]
        thing_object_id = shapes[idx2]["object_id"]
        object_ = shape["label"]
        object_object_id = shapes[idx]["object_id"]
        
        # connect objects
        connect_objects = ["porch", "door", "walkway", "landing"]
        
        if thing in connect_objects:             
            predicate = "connect_to"
            relation = fill_relation(shape, predicate, shapes[idx2])
            relation_list.append(relation)   
            
    isPrint = True
    isPrint = False

    if isPrint:        
        print("Step (id) connect to:", object_object_id)       
        [print(r['object']["name"], r['object']['object_id']) for r in relation_list]            
        print("")            
    print("")   
    
    print("Found {} relationships for {} - {}\n".format(len(relation_list), shapes[idx]["label"], shapes[idx]["object_id"]))

    
    return relation_list

# %% [markdown]
# ## porch relation

# %%
def init_porch_relation(idx, shapes, geo_series):
    
    shape = shapes[idx]
    relation_list = []
    polygon = geo_series[idx]
    
    centroids = geo_series.centroid    
    
    # if a door (centroids) inside a porch:
    centroids.within(geo_series[idx])
#     print("centroids:", centroids)
    insides_idx = centroids[centroids.within(geo_series[idx])].index
#     print("idx, shape.label", idx, shape["label"])
#     print("insides_idx:", idx, centroids.within(geo_series[idx]))
 
    predicate = ''
    for idx2 in insides_idx:
        thing = shapes[idx2]["label"]
        if "door" in thing.lower():  
            # connects to door            
            predicate = "connect_to"
            relation = fill_relation(shape, predicate, shapes[idx2])
            relation_list.append(relation)   
            
    isPrint = True
    isPrint = False
    if isPrint: 
        if len(relation_list) > 0:
            print(shapes[idx]["label"], shapes[idx]["object_id"], predicate)       
            [print(r['object']["name"], r['object']['object_id']) for r in relation_list]            
        else:
            print("No door is founded in porch:", shapes[idx]["object_id"])
            
#         print("")   
#     print(relation_list)
    print("Found {} relationships for {} - {}\n".format(len(relation_list), shapes[idx]["label"], shapes[idx]["object_id"]))
     
    return relation_list

# %% [markdown]
# ## sidewalk relationship

# %%
def init_sidewalk_relation():
    shape = shapes[idx]
    relation_list = []
    polygon = geo_series[idx]
    distances = geo_series.distance(polygon)
#     print(distances)
    
    bounds = geo_series.bounds
    widths = bounds.maxx - bounds.minx
    heights = bounds.maxy - bounds.miny
# #     print(widths)
#     print(heights)
    
    near_ratio = 0.2 # assume that sidewalk can connect the object within near_ratio * height.
    
    sidewalk_height = heights[idx]
    near_idx = distances[distances < near_ratio * step_height].index
#     print("type(insides):", type((near_idx)))
#     print("near_idx:", near_idx)

    for idx2 in near_idx:
        thing = shapes[idx2]["label"]
        if thing == "road":
            predicate = "along_with"
            relation = fill_relation(shape, predicate, shapes[idx2])
            relation_list.append(relation) 
  
        # connect objects
        connect_objects = ["door", "walkway", "driveway", "driveway-apron", "curb-cut", "pathway"]
        
        if thing in connect_objects:             
            predicate = "connect_to"
            relation = fill_relation(shape, predicate, shapes[idx2])
            relation_list.append(relation)   
            
    isPrint = True
    isPrint = False

    if isPrint:        
        print("Step (id) connect to:", object_object_id)       
        [print(r['object']["name"], r['object']['object_id']) for r in relation_list]            
        print("")            
    print("")   
    
    print("Found {} relationships for {} - {}\n".format(len(relation_list), shapes[idx]["label"], shapes[idx]["object_id"]))

    
    return relation_list

# %% [markdown]
# ## Init relations

# %%
def initRelation(shapes):
    
    walkable_connection_list = []
    infront_of_list = []
    
    relations = {"relationship":[]}
    
    geo_series = getGeoSeries(shapes)
    
    for idx, shape in enumerate(shapes):
        label = shape["label"]
        
        # house components
        if "house" in label.lower():
            house_relations = init_house_relation(idx, shapes, geo_series)            
            
        # step connect to porch, walkway, door
        if "step" in label.lower():
            step_relations = init_step_relation(idx, shapes, geo_series)
            
        # porch connects to door
        if "porch" in label.lower():
            if not "-skirt" in label.lower():
                step_relations = init_porch_relation(idx, shapes, geo_series)
                
        # sidewalk along with road
        if "sidewalk" in label.lower():            
            sidewalk_relations = init_sidewalk_relation(idx, shapes, geo_series)
             
 
            
initRelation(shapes)
# Out:
# Found 26 relationships for single-house - 1
#
#
# Found 3 relationships for step - 3
#
# Found 1 relationships for porch - 4
#
#
# Found 1 relationships for step - 11
#
#
# Found 1 relationships for step - 12
#
# Found 13 relationships for single-house - 32
#
#
# Found 1 relationships for step - 33
#
# Found 2 relationships for porch - 38
#
# Found 7 relationships for single-house - 52
#
# Found 0 relationships for porch - 56

# %%
        # position of hourse components
        # porch in the middel/right/left part 
        # window in the middle/right/left part 
        # door in the middle/right/left part
        
        # drive way in the fron of garage 
        
        # porch-skirt is component of porch
            
        # house and others
        # lawn in the front of house
        
        # house is in the right/left of another house
        
        # sidewalk in the front of lawn
        
        # parking-strip along with road
        
        # flowerbed within lawn
        
        # trees within flowerbed
        
        
        # tree in the right part of parking-strip
        
        
        # at the right/left side of
        
          
        # road and its neighbors
        # strip near road
        
        # sidewalk along with road

# %%
g.distance(g[0])
# Out:
# 0        0.000000
# 1        0.000000
# 2        0.000000
# 3        0.000000
# 4        0.000000
# 5        0.000000
# 6        0.000000
# 7        0.000000
# 8        0.000000
# 9        0.000000
# 10      73.636364
# 11     950.216450
# 12     628.138528
# 13     985.204991
# 14     560.499109
# 15     193.398268
# 16     850.359527
# 17     949.350649
# 18    1131.890332
# 19     739.033189
# 20     528.715729
# 21     919.985570
# 22     594.588745
# 23     704.112554
# 24    1024.747475
# 25    1170.653907
# 26    1198.724083
# 27    1083.080808
# 28     214.632035
# 29      34.632035
# 30     346.494949
# 31     152.272727
# 32     223.272727
# 33       0.000000
# 34       0.000000
# 35     840.944382
# 36     523.953824
# 37    1107.173779
# 38      27.272727
# dtype: float64

# %% [markdown]
# # Process the json

# %%
for jfile in files[:]:
    print(jfile)
    f = open(jfile, 'r')
    jdata = json.load(f)
    f.close()
#     
#     print(jdata["shapes"])
#     print(jdata["shapes"][0].keys())
    shapes = jdata["shapes"]
    
    all_ids = getShape_all_id(shapes)
    print("all_ids:", all_ids)
    
    Whether_duplicateID = isDuplicateID(all_ids)
    print("isDuplicateID:", Whether_duplicateID)
    if Whether_duplicateID:
        renewShapeId(shapes)
    
    gpd_series = getGeoSeries(shapes)
    
    
#     print(len(all_ids))
    
    for idx, shape in enumerate(shapes[:]):
         
        
        # read attributes
        attributes = shape.get("attributes", {})
        
        # add object_id
        object_id = shape.get("object_id", None)
        if not object_id:
            object_id = idx + 1
            
        shapes[idx]["object_id"] = object_id
        print("object_id:", shapes[idx]["object_id"])
        
        
        label = shape["label"]
        print("raw label:", label)
        shape["raw_label"] = label
        fields = label.split("_")
        
        
        
        # process label: remove attributes
        shape["label"] = fields[0]
        print("raw fields:", fields)
#         print("raw len of fields:", len(fields))
        
        
        if len(fields)>1:            
            fields = fields[1:]
        
        else:
            fields = []
            
        # process storey_cnt for house
        if ("house" in label) and (len(fields) > 0):
            if fields[0].isnumeric():
                attributes["storey_cnt"] = fields[0]
                print("Added attributes.storey_cnt: ", attributes["storey_cnt"])
                
                
        # process step_cnt for step
        if ("step" in label) and (len(fields) > 0):
            if fields[0].isnumeric():
                attributes["step_cnt"] = fields[0]
                print("Added attributes.step_cnt: ", attributes["step_cnt"])
                                
                
                
        shape['attributes'] = attributes
         
            
        print("new label:", shape["label"])
        print("attributes:", attributes)
        print("attributes filed values:", fields)
        print("")
        
#     with open('data.txt', 'w') as outfile:
    f2 = open(jfile, 'w')
    json.dump(jdata, f2, indent=2)
    f2.close()
#     json.dump()
# Out:
# L:\Datasets\ocean_city\processed_json\100_oUUwCL6RJ53TmRjrP5u1SQ_32.55.json
# all_ids: [None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# isDuplicateID: True
# object_id: 1
# raw label: front-door
# raw fields: ['front-door']
# new label: front-door
# attributes: {}
# attributes filed values: []
#
# object_id: 2
# raw label: step_4
# raw fields: ['step', '4']
# Added attributes.step_cnt:  4
# new label: step
# attributes: {'step_cnt': '4'}
# attributes filed values: ['4']
#
# object_id: 3
# raw label: domer-window
# raw fields: ['domer-window']
# new label: domer-window
# attributes: {}
# attributes filed values: []
#
# object_id: 4
# raw label: domer-window
# raw fields: ['domer-window']
# new label: domer-window
# attributes: {}
# attributes filed values: []
#
# object_id: 5
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 6
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 7
# raw label: porch
# raw fields: ['porch']
# new label: porch
# attributes: {}
# attributes filed values: []
#
# object_id: 8
# raw label: ranch
# raw fields: ['ranch']
# new label: ranch
# attributes: {}
# attributes filed values: []
#
# object_id: 9
# raw label: step_3
# raw fields: ['step', '3']
# Added attributes.step_cnt:  3
# new label: step
# attributes: {'step_cnt': '3'}
# attributes filed values: ['3']
#
# object_id: 10
# raw label: porch
# raw fields: ['porch']
# new label: porch
# attributes: {}
# attributes filed values: []
#
# object_id: 11
# raw label: gable-window_round
# raw fields: ['gable-window', 'round']
# new label: gable-window
# attributes: {}
# attributes filed values: ['round']
#
# object_id: 12
# raw label: house
# raw fields: ['house']
# new label: house
# attributes: {}
# attributes filed values: []
#
# object_id: 13
# raw label: garage
# raw fields: ['garage']
# new label: garage
# attributes: {}
# attributes filed values: []
#
# object_id: 14
# raw label: single-house_2
# raw fields: ['single-house', '2']
# Added attributes.storey_cnt:  2
# new label: single-house
# attributes: {'storey_cnt': '2'}
# attributes filed values: ['2']
#
# L:\Datasets\ocean_city\processed_json\101_ZfvvGESbNnVG8yFN9PORqQ_24.2.json
# all_ids: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# isDuplicateID: True
# object_id: 1
# raw label: single-house_2
# raw fields: ['single-house', '2']
# Added attributes.storey_cnt:  2
# new label: single-house
# attributes: {'storey_cnt': '2'}
# attributes filed values: ['2']
#
# object_id: 2
# raw label: front-door
# raw fields: ['front-door']
# new label: front-door
# attributes: {}
# attributes filed values: []
#
# object_id: 3
# raw label: porch
# raw fields: ['porch']
# new label: porch
# attributes: {}
# attributes filed values: []
#
# object_id: 4
# raw label: step_2
# raw fields: ['step', '2']
# Added attributes.step_cnt:  2
# new label: step
# attributes: {'step_cnt': '2'}
# attributes filed values: ['2']
#
# object_id: 5
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 6
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# object_id: 7
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# object_id: 8
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# object_id: 9
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# object_id: 10
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# object_id: 11
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# object_id: 12
# raw label: domer-window
# raw fields: ['domer-window']
# new label: domer-window
# attributes: {}
# attributes filed values: []
#
# object_id: 13
# raw label: domer-window
# raw fields: ['domer-window']
# new label: domer-window
# attributes: {}
# attributes filed values: []
#
# object_id: 14
# raw label: house
# raw fields: ['house']
# new label: house
# attributes: {}
# attributes filed values: []
#
# object_id: 15
# raw label: step_4
# raw fields: ['step', '4']
# Added attributes.step_cnt:  4
# new label: step
# attributes: {'step_cnt': '4'}
# attributes filed values: ['4']
#
# object_id: 16
# raw label: porch
# raw fields: ['porch']
# new label: porch
# attributes: {}
# attributes filed values: []
#
# L:\Datasets\ocean_city\processed_json\102_aDNd7B-rqtKMpcw-Nvp5JQ_225.11.json
# all_ids: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# isDuplicateID: True
# object_id: 1
# raw label: single-house_3
# raw fields: ['single-house', '3']
# Added attributes.storey_cnt:  3
# new label: single-house
# attributes: {'storey_cnt': '3'}
# attributes filed values: ['3']
#
# object_id: 2
# raw label: garage
# raw fields: ['garage']
# new label: garage
# attributes: {}
# attributes filed values: []
#
# object_id: 3
# raw label: deck
# raw fields: ['deck']
# new label: deck
# attributes: {}
# attributes filed values: []
#
# object_id: 4
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 5
# raw label: door
# raw fields: ['door']
# new label: door
# attributes: {}
# attributes filed values: []
#
# object_id: 6
# raw label: balcony
# raw fields: ['balcony']
# new label: balcony
# attributes: {}
# attributes filed values: []
#
# object_id: 7
# raw label: front-door
# raw fields: ['front-door']
# new label: front-door
# attributes: {}
# attributes filed values: []
#
# object_id: 8
# raw label: stair
# raw fields: ['stair']
# new label: stair
# attributes: {}
# attributes filed values: []
#
# object_id: 9
# raw label: door
# raw fields: ['door']
# new label: door
# attributes: {}
# attributes filed values: []
#
# object_id: 10
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 11
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 12
# raw label: louver
# raw fields: ['louver']
# new label: louver
# attributes: {}
# attributes filed values: []
#
# object_id: 13
# raw label: house
# raw fields: ['house']
# new label: house
# attributes: {}
# attributes filed values: []
#
# object_id: 14
# raw label: house-group
# raw fields: ['house-group']
# new label: house-group
# attributes: {}
# attributes filed values: []
#
# object_id: 15
# raw label: drive-way
# raw fields: ['drive-way']
# new label: drive-way
# attributes: {}
# attributes filed values: []
#
# L:\Datasets\ocean_city\processed_json\103_cC3D4p-Lj3pUVQ03gdovQw_45.33.json
# all_ids: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# isDuplicateID: True
# object_id: 1
# raw label: single-house_2
# raw fields: ['single-house', '2']
# Added attributes.storey_cnt:  2
# new label: single-house
# attributes: {'storey_cnt': '2'}
# attributes filed values: ['2']
#
# object_id: 2
# raw label: step_6
# raw fields: ['step', '6']
# Added attributes.step_cnt:  6
# new label: step
# attributes: {'step_cnt': '6'}
# attributes filed values: ['6']
#
# object_id: 3
# raw label: front-door
# raw fields: ['front-door']
# new label: front-door
# attributes: {}
# attributes filed values: []
#
# object_id: 4
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 5
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 6
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 7
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 8
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 9
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 10
# raw label: gable-vent_round
# raw fields: ['gable-vent', 'round']
# new label: gable-vent
# attributes: {}
# attributes filed values: ['round']
#
# object_id: 11
# raw label: balcony
# raw fields: ['balcony']
# new label: balcony
# attributes: {}
# attributes filed values: []
#
# object_id: 12
# raw label: porch
# raw fields: ['porch']
# new label: porch
# attributes: {}
# attributes filed values: []
#
# object_id: 13
# raw label: foundation
# raw fields: ['foundation']
# new label: foundation
# attributes: {}
# attributes filed values: []
#
# object_id: 14
# raw label: single-house_2
# raw fields: ['single-house', '2']
# Added attributes.storey_cnt:  2
# new label: single-house
# attributes: {'storey_cnt': '2'}
# attributes filed values: ['2']
#
# object_id: 15
# raw label: house
# raw fields: ['house']
# new label: house
# attributes: {}
# attributes filed values: []
#
# object_id: 16
# raw label: garage
# raw fields: ['garage']
# new label: garage
# attributes: {}
# attributes filed values: []
#
# object_id: 17
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 18
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 19
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 20
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 21
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
# object_id: 22
# raw label: gable-vent
# raw fields: ['gable-vent']
# new label: gable-vent
# attributes: {}
# attributes filed values: []
#
# object_id: 23
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 24
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 25
# raw label: garage
# raw fields: ['garage']
# new label: garage
# attributes: {}
# attributes filed values: []
#
# object_id: 26
# raw label: single-house_2
# raw fields: ['single-house', '2']
# Added attributes.storey_cnt:  2
# new label: single-house
# attributes: {'storey_cnt': '2'}
# attributes filed values: ['2']
#
# object_id: 27
# raw label: garage
# raw fields: ['garage']
# new label: garage
# attributes: {}
# attributes filed values: []
#
# object_id: 28
# raw label: domer-window
# raw fields: ['domer-window']
# new label: domer-window
# attributes: {}
# attributes filed values: []
#
# object_id: 29
# raw label: chimney
# raw fields: ['chimney']
# new label: chimney
# attributes: {}
# attributes filed values: []
#
# object_id: 30
# raw label: house
# raw fields: ['house']
# new label: house
# attributes: {}
# attributes filed values: []
#
# object_id: 31
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# L:\Datasets\ocean_city\processed_json\104_izMCA8QLT_KCRokDsm_Zvg_319.71.json
# all_ids: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# isDuplicateID: True
# object_id: 1
# raw label: single-house_3
# raw fields: ['single-house', '3']
# Added attributes.storey_cnt:  3
# new label: single-house
# attributes: {'storey_cnt': '3'}
# attributes filed values: ['3']
#
# object_id: 2
# raw label: garage
# raw fields: ['garage']
# new label: garage
# attributes: {}
# attributes filed values: []
#
# object_id: 3
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 4
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 5
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 6
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 7
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 8
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 9
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 10
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# object_id: 11
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# object_id: 12
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# object_id: 13
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# object_id: 14
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# object_id: 15
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# object_id: 16
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# object_id: 17
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# object_id: 18
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# object_id: 19
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# object_id: 20
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# object_id: 21
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# object_id: 22
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# object_id: 23
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# object_id: 24
# raw label: gable-vent
# raw fields: ['gable-vent']
# new label: gable-vent
# attributes: {}
# attributes filed values: []
#
# object_id: 25
# raw label: gable-vent
# raw fields: ['gable-vent']
# new label: gable-vent
# attributes: {}
# attributes filed values: []
#
# object_id: 26
# raw label: single-house_2
# raw fields: ['single-house', '2']
# Added attributes.storey_cnt:  2
# new label: single-house
# attributes: {'storey_cnt': '2'}
# attributes filed values: ['2']
#
# object_id: 27
# raw label: single-house_2
# raw fields: ['single-house', '2']
# Added attributes.storey_cnt:  2
# new label: single-house
# attributes: {'storey_cnt': '2'}
# attributes filed values: ['2']
#
# object_id: 28
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 29
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 30
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 31
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# object_id: 32
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# object_id: 33
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# object_id: 34
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# object_id: 35
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# L:\Datasets\ocean_city\processed_json\105_MhPqVhBXRTVCcuw2F7B7sA_67.55.json
# all_ids: [None, None, None, None, None, None, None, None, None]
# isDuplicateID: True
# object_id: 1
# raw label: house
# raw fields: ['house']
# new label: house
# attributes: {}
# attributes filed values: []
#
# object_id: 2
# raw label: balcony
# raw fields: ['balcony']
# new label: balcony
# attributes: {}
# attributes filed values: []
#
# object_id: 3
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 4
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 5
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 6
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 7
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 8
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 9
# raw label: door
# raw fields: ['door']
# new label: door
# attributes: {}
# attributes filed values: []
#
# L:\Datasets\ocean_city\processed_json\106_LdXGcrXpLQc28rFjF__cKQ_0.43.json
# all_ids: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# isDuplicateID: True
# object_id: 1
# raw label: single-house_2
# raw fields: ['single-house', '2']
# Added attributes.storey_cnt:  2
# new label: single-house
# attributes: {'storey_cnt': '2'}
# attributes filed values: ['2']
#
# object_id: 2
# raw label: garage
# raw fields: ['garage']
# new label: garage
# attributes: {}
# attributes filed values: []
#
# object_id: 3
# raw label: door
# raw fields: ['door']
# new label: door
# attributes: {}
# attributes filed values: []
#
# object_id: 4
# raw label: step_3
# raw fields: ['step', '3']
# Added attributes.step_cnt:  3
# new label: step
# attributes: {'step_cnt': '3'}
# attributes filed values: ['3']
#
# object_id: 5
# raw label: foundation
# raw fields: ['foundation']
# new label: foundation
# attributes: {}
# attributes filed values: []
#
# object_id: 6
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 7
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 8
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 9
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 10
# raw label: porch
# raw fields: ['porch']
# new label: porch
# attributes: {}
# attributes filed values: []
#
# object_id: 11
# raw label: garage
# raw fields: ['garage']
# new label: garage
# attributes: {}
# attributes filed values: []
#
# object_id: 12
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 13
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 14
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 15
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 16
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 17
# raw label: window-round-top-extended-leg
# raw fields: ['window-round-top-extended-leg']
# new label: window-round-top-extended-leg
# attributes: {}
# attributes filed values: []
#
# object_id: 18
# raw label: door
# raw fields: ['door']
# new label: door
# attributes: {}
# attributes filed values: []
#
# object_id: 19
# raw label: step_4
# raw fields: ['step', '4']
# Added attributes.step_cnt:  4
# new label: step
# attributes: {'step_cnt': '4'}
# attributes filed values: ['4']
#
# object_id: 20
# raw label: single-house_2
# raw fields: ['single-house', '2']
# Added attributes.storey_cnt:  2
# new label: single-house
# attributes: {'storey_cnt': '2'}
# attributes filed values: ['2']
#
# object_id: 21
# raw label: single-house_2
# raw fields: ['single-house', '2']
# Added attributes.storey_cnt:  2
# new label: single-house
# attributes: {'storey_cnt': '2'}
# attributes filed values: ['2']
#
# object_id: 22
# raw label: step_3
# raw fields: ['step', '3']
# Added attributes.step_cnt:  3
# new label: step
# attributes: {'step_cnt': '3'}
# attributes filed values: ['3']
#
# object_id: 23
# raw label: door
# raw fields: ['door']
# new label: door
# attributes: {}
# attributes filed values: []
#
# object_id: 24
# raw label: balcony
# raw fields: ['balcony']
# new label: balcony
# attributes: {}
# attributes filed values: []
#
# object_id: 25
# raw label: house-group
# raw fields: ['house-group']
# new label: house-group
# attributes: {}
# attributes filed values: []
#
# object_id: 26
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 27
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 28
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 29
# raw label: window-round-top-extended-leg
# raw fields: ['window-round-top-extended-leg']
# new label: window-round-top-extended-leg
# attributes: {}
# attributes filed values: []
#
# object_id: 30
# raw label: drive-way_brick
# raw fields: ['drive-way', 'brick']
# new label: drive-way
# attributes: {}
# attributes filed values: ['brick']
#
# object_id: 31
# raw label: drive-way
# raw fields: ['drive-way']
# new label: drive-way
# attributes: {}
# attributes filed values: []
#
# object_id: 32
# raw label: grass
# raw fields: ['grass']
# new label: grass
# attributes: {}
# attributes filed values: []
#
# object_id: 33
# raw label: grass
# raw fields: ['grass']
# new label: grass
# attributes: {}
# attributes filed values: []
#
# object_id: 34
# raw label: drive-way
# raw fields: ['drive-way']
# new label: drive-way
# attributes: {}
# attributes filed values: []
#
# object_id: 35
# raw label: road
# raw fields: ['road']
# new label: road
# attributes: {}
# attributes filed values: []
#
# object_id: 36
# raw label: sidewalk
# raw fields: ['sidewalk']
# new label: sidewalk
# attributes: {}
# attributes filed values: []
#
# L:\Datasets\ocean_city\processed_json\107_7HfRX3diZje3jJgELHi5Kg_238.41.json
# all_ids: [None, None, None, None, None, None, None, None, None, None, None, None, None]
# isDuplicateID: True
# object_id: 1
# raw label: single-house_2
# raw fields: ['single-house', '2']
# Added attributes.storey_cnt:  2
# new label: single-house
# attributes: {'storey_cnt': '2'}
# attributes filed values: ['2']
#
# object_id: 2
# raw label: house-group
# raw fields: ['house-group']
# new label: house-group
# attributes: {}
# attributes filed values: []
#
# object_id: 3
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 4
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 5
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 6
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 7
# raw label: door
# raw fields: ['door']
# new label: door
# attributes: {}
# attributes filed values: []
#
# object_id: 8
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 9
# raw label: step_3
# raw fields: ['step', '3']
# Added attributes.step_cnt:  3
# new label: step
# attributes: {'step_cnt': '3'}
# attributes filed values: ['3']
#
# object_id: 10
# raw label: stair
# raw fields: ['stair']
# new label: stair
# attributes: {}
# attributes filed values: []
#
# object_id: 11
# raw label: porch
# raw fields: ['porch']
# new label: porch
# attributes: {}
# attributes filed values: []
#
# object_id: 12
# raw label: balcony
# raw fields: ['balcony']
# new label: balcony
# attributes: {}
# attributes filed values: []
#
# object_id: 13
# raw label: bungalow
# raw fields: ['bungalow']
# new label: bungalow
# attributes: {}
# attributes filed values: []
#
# L:\Datasets\ocean_city\processed_json\108_ZqBO-3Fx_roeVBNiLBnSVA_219.47.json
# all_ids: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# isDuplicateID: True
# object_id: 1
# raw label: single-house_2
# raw fields: ['single-house', '2']
# Added attributes.storey_cnt:  2
# new label: single-house
# attributes: {'storey_cnt': '2'}
# attributes filed values: ['2']
#
# object_id: 2
# raw label: step_3
# raw fields: ['step', '3']
# Added attributes.step_cnt:  3
# new label: step
# attributes: {'step_cnt': '3'}
# attributes filed values: ['3']
#
# object_id: 3
# raw label: front-door
# raw fields: ['front-door']
# new label: front-door
# attributes: {}
# attributes filed values: []
#
# object_id: 4
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 5
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 6
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 7
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 8
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 9
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 10
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 11
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 12
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# object_id: 13
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# object_id: 14
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# object_id: 15
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# object_id: 16
# raw label: chimney
# raw fields: ['chimney']
# new label: chimney
# attributes: {}
# attributes filed values: []
#
# object_id: 17
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 18
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 19
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 20
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 21
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# object_id: 22
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# object_id: 23
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# object_id: 24
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# object_id: 25
# raw label: single-house_2
# raw fields: ['single-house', '2']
# Added attributes.storey_cnt:  2
# new label: single-house
# attributes: {'storey_cnt': '2'}
# attributes filed values: ['2']
#
# object_id: 26
# raw label: chimney
# raw fields: ['chimney']
# new label: chimney
# attributes: {}
# attributes filed values: []
#
# object_id: 27
# raw label: stair
# raw fields: ['stair']
# new label: stair
# attributes: {}
# attributes filed values: []
#
# object_id: 28
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 29
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 30
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 31
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 32
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 33
# raw label: road
# raw fields: ['road']
# new label: road
# attributes: {}
# attributes filed values: []
#
# object_id: 34
# raw label: sidewalk
# raw fields: ['sidewalk']
# new label: sidewalk
# attributes: {}
# attributes filed values: []
#
# object_id: 35
# raw label: sidewalk
# raw fields: ['sidewalk']
# new label: sidewalk
# attributes: {}
# attributes filed values: []
#
# L:\Datasets\ocean_city\processed_json\109__vH4I71u2hkWYNXJ5WDA_A_227.84.json
# all_ids: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# isDuplicateID: True
# object_id: 1
# raw label: single-house_2
# raw fields: ['single-house', '2']
# Added attributes.storey_cnt:  2
# new label: single-house
# attributes: {'storey_cnt': '2'}
# attributes filed values: ['2']
#
# object_id: 2
# raw label: stair
# raw fields: ['stair']
# new label: stair
# attributes: {}
# attributes filed values: []
#
# object_id: 3
# raw label: step_4
# raw fields: ['step', '4']
# Added attributes.step_cnt:  4
# new label: step
# attributes: {'step_cnt': '4'}
# attributes filed values: ['4']
#
# object_id: 4
# raw label: door
# raw fields: ['door']
# new label: door
# attributes: {}
# attributes filed values: []
#
# object_id: 5
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 6
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 7
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 8
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 9
# raw label: domer-window
# raw fields: ['domer-window']
# new label: domer-window
# attributes: {}
# attributes filed values: []
#
# object_id: 10
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 11
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 12
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 13
# raw label: single-house_2
# raw fields: ['single-house', '2']
# Added attributes.storey_cnt:  2
# new label: single-house
# attributes: {'storey_cnt': '2'}
# attributes filed values: ['2']
#
# object_id: 14
# raw label: sidewalk
# raw fields: ['sidewalk']
# new label: sidewalk
# attributes: {}
# attributes filed values: []
#
# object_id: 15
# raw label: road
# raw fields: ['road']
# new label: road
# attributes: {}
# attributes filed values: []
#
# object_id: 16
# raw label: parking-strip
# raw fields: ['parking-strip']
# new label: parking-strip
# attributes: {}
# attributes filed values: []
#
# L:\Datasets\ocean_city\processed_json\10_piJ3-HBctCPJ9qejZZesEQ_121.73.json
# all_ids: [None, None]
# isDuplicateID: True
# object_id: 1
# raw label: town-house_3
# raw fields: ['town-house', '3']
# Added attributes.storey_cnt:  3
# new label: town-house
# attributes: {'storey_cnt': '3'}
# attributes filed values: ['3']
#
# object_id: 2
# raw label: house
# raw fields: ['house']
# new label: house
# attributes: {}
# attributes filed values: []
#
# L:\Datasets\ocean_city\processed_json\110_oMm_5LNoLZwRbeHZDaUcrQ_222.35.json
# all_ids: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# isDuplicateID: True
# object_id: 1
# raw label: single-house
# raw fields: ['single-house']
# new label: single-house
# attributes: {}
# attributes filed values: []
#
# object_id: 2
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 3
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 4
# raw label: gable-window
# raw fields: ['gable-window']
# new label: gable-window
# attributes: {}
# attributes filed values: []
#
# object_id: 5
# raw label: step_5
# raw fields: ['step', '5']
# Added attributes.step_cnt:  5
# new label: step
# attributes: {'step_cnt': '5'}
# attributes filed values: ['5']
#
# object_id: 6
# raw label: single-house_2
# raw fields: ['single-house', '2']
# Added attributes.storey_cnt:  2
# new label: single-house
# attributes: {'storey_cnt': '2'}
# attributes filed values: ['2']
#
# object_id: 7
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 8
# raw label: door
# raw fields: ['door']
# new label: door
# attributes: {}
# attributes filed values: []
#
# object_id: 9
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 10
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 11
# raw label: door
# raw fields: ['door']
# new label: door
# attributes: {}
# attributes filed values: []
#
# object_id: 12
# raw label: door
# raw fields: ['door']
# new label: door
# attributes: {}
# attributes filed values: []
#
# object_id: 13
# raw label: step_4
# raw fields: ['step', '4']
# Added attributes.step_cnt:  4
# new label: step
# attributes: {'step_cnt': '4'}
# attributes filed values: ['4']
#
# object_id: 14
# raw label: door
# raw fields: ['door']
# new label: door
# attributes: {}
# attributes filed values: []
#
# object_id: 15
# raw label: basement-window
# raw fields: ['basement-window']
# new label: basement-window
# attributes: {}
# attributes filed values: []
#
# object_id: 16
# raw label: basement-window
# raw fields: ['basement-window']
# new label: basement-window
# attributes: {}
# attributes filed values: []
#
# object_id: 17
# raw label: foundation
# raw fields: ['foundation']
# new label: foundation
# attributes: {}
# attributes filed values: []
#
# object_id: 18
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 19
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 20
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 21
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 22
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 23
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 24
# raw label: house
# raw fields: ['house']
# new label: house
# attributes: {}
# attributes filed values: []
#
# object_id: 25
# raw label: step_6
# raw fields: ['step', '6']
# Added attributes.step_cnt:  6
# new label: step
# attributes: {'step_cnt': '6'}
# attributes filed values: ['6']
#
# object_id: 26
# raw label: road
# raw fields: ['road']
# new label: road
# attributes: {}
# attributes filed values: []
#
# object_id: 27
# raw label: drive-way
# raw fields: ['drive-way']
# new label: drive-way
# attributes: {}
# attributes filed values: []
#
# object_id: 28
# raw label: sidewalk
# raw fields: ['sidewalk']
# new label: sidewalk
# attributes: {}
# attributes filed values: []
#
# object_id: 29
# raw label: house-group
# raw fields: ['house-group']
# new label: house-group
# attributes: {}
# attributes filed values: []
#
# object_id: 30
# raw label: house-group
# raw fields: ['house-group']
# new label: house-group
# attributes: {}
# attributes filed values: []
#
# L:\Datasets\ocean_city\processed_json\111_za8cyYaw9Zkj8FS3S8z-qw_221.62.json
# all_ids: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# isDuplicateID: True
# object_id: 1
# raw label: single-house_2
# raw fields: ['single-house', '2']
# Added attributes.storey_cnt:  2
# new label: single-house
# attributes: {'storey_cnt': '2'}
# attributes filed values: ['2']
#
# object_id: 2
# raw label: garage
# raw fields: ['garage']
# new label: garage
# attributes: {}
# attributes filed values: []
#
# object_id: 3
# raw label: step_12
# raw fields: ['step', '12']
# Added attributes.step_cnt:  12
# new label: step
# attributes: {'step_cnt': '12'}
# attributes filed values: ['12']
#
# object_id: 4
# raw label: front-door
# raw fields: ['front-door']
# new label: front-door
# attributes: {}
# attributes filed values: []
#
# object_id: 5
# raw label: porch
# raw fields: ['porch']
# new label: porch
# attributes: {}
# attributes filed values: []
#
# object_id: 6
# raw label: deck
# raw fields: ['deck']
# new label: deck
# attributes: {}
# attributes filed values: []
#
# object_id: 7
# raw label: balcony
# raw fields: ['balcony']
# new label: balcony
# attributes: {}
# attributes filed values: []
#
# object_id: 8
# raw label: single-house_2
# raw fields: ['single-house', '2']
# Added attributes.storey_cnt:  2
# new label: single-house
# attributes: {'storey_cnt': '2'}
# attributes filed values: ['2']
#
# object_id: 9
# raw label: garage
# raw fields: ['garage']
# new label: garage
# attributes: {}
# attributes filed values: []
#
# object_id: 10
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 11
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 12
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 13
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 14
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 15
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 16
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 17
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 18
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 19
# raw label: gable-window
# raw fields: ['gable-window']
# new label: gable-window
# attributes: {}
# attributes filed values: []
#
# object_id: 20
# raw label: single-house_2
# raw fields: ['single-house', '2']
# Added attributes.storey_cnt:  2
# new label: single-house
# attributes: {'storey_cnt': '2'}
# attributes filed values: ['2']
#
# object_id: 21
# raw label: door
# raw fields: ['door']
# new label: door
# attributes: {}
# attributes filed values: []
#
# object_id: 22
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 23
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 24
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 25
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 26
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 27
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 28
# raw label: window-eyebow_extended_leg
# raw fields: ['window-eyebow', 'extended', 'leg']
# new label: window-eyebow
# attributes: {}
# attributes filed values: ['extended', 'leg']
#
# object_id: 29
# raw label: window-eyebow_extended_leg
# raw fields: ['window-eyebow', 'extended', 'leg']
# new label: window-eyebow
# attributes: {}
# attributes filed values: ['extended', 'leg']
#
# object_id: 30
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 31
# raw label: foundation
# raw fields: ['foundation']
# new label: foundation
# attributes: {}
# attributes filed values: []
#
# L:\Datasets\ocean_city\processed_json\112_PeSBBfnHQpCUcd5ZEn2IRw_214.13.json
# all_ids: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# isDuplicateID: True
# object_id: 1
# raw label: single-house_2
# raw fields: ['single-house', '2']
# Added attributes.storey_cnt:  2
# new label: single-house
# attributes: {'storey_cnt': '2'}
# attributes filed values: ['2']
#
# object_id: 2
# raw label: garage
# raw fields: ['garage']
# new label: garage
# attributes: {}
# attributes filed values: []
#
# object_id: 3
# raw label: step_3
# raw fields: ['step', '3']
# Added attributes.step_cnt:  3
# new label: step
# attributes: {'step_cnt': '3'}
# attributes filed values: ['3']
#
# object_id: 4
# raw label: front-door
# raw fields: ['front-door']
# new label: front-door
# attributes: {}
# attributes filed values: []
#
# object_id: 5
# raw label: porch
# raw fields: ['porch']
# new label: porch
# attributes: {}
# attributes filed values: []
#
# object_id: 6
# raw label: balcony
# raw fields: ['balcony']
# new label: balcony
# attributes: {}
# attributes filed values: []
#
# object_id: 7
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 8
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 9
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# object_id: 10
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# object_id: 11
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# object_id: 12
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# object_id: 13
# raw label: road
# raw fields: ['road']
# new label: road
# attributes: {}
# attributes filed values: []
#
# object_id: 14
# raw label: sidewalk
# raw fields: ['sidewalk']
# new label: sidewalk
# attributes: {}
# attributes filed values: []
#
# object_id: 15
# raw label: drive-way
# raw fields: ['drive-way']
# new label: drive-way
# attributes: {}
# attributes filed values: []
# object_id: 16
# raw label: drive-way
# raw fields: ['drive-way']
# new label: drive-way
# attributes: {}
# attributes filed values: []
#
# object_id: 17
# raw label: garage
# raw fields: ['garage']
# new label: garage
# attributes: {}
# attributes filed values: []
#
# object_id: 18
# raw label: single-house_2
# raw fields: ['single-house', '2']
# Added attributes.storey_cnt:  2
# new label: single-house
# attributes: {'storey_cnt': '2'}
# attributes filed values: ['2']
#
# object_id: 19
# raw label: deck
# raw fields: ['deck']
# new label: deck
# attributes: {}
# attributes filed values: []
#
# object_id: 20
# raw label: porch
# raw fields: ['porch']
# new label: porch
# attributes: {}
# attributes filed values: []
#
# object_id: 21
# raw label: door
# raw fields: ['door']
# new label: door
# attributes: {}
# attributes filed values: []
#
# object_id: 22
# raw label: step_3
# raw fields: ['step', '3']
# Added attributes.step_cnt:  3
# new label: step
# attributes: {'step_cnt': '3'}
# attributes filed values: ['3']
#
# object_id: 23
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 24
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 25
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 26
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 27
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 28
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 29
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 30
# raw label: door
# raw fields: ['door']
# new label: door
# attributes: {}
# attributes filed values: []
#
# L:\Datasets\ocean_city\processed_json\113_iaY766f_G_B0IwgxMtBMQw_232.33.json
# all_ids: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# isDuplicateID: True
# object_id: 1
# raw label: single-house
# raw fields: ['single-house']
# new label: single-house
# attributes: {}
# attributes filed values: []
#
# object_id: 2
# raw label: deck
# raw fields: ['deck']
# new label: deck
# attributes: {}
# attributes filed values: []
#
# object_id: 3
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 4
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 5
# raw label: door
# raw fields: ['door']
# new label: door
# attributes: {}
# attributes filed values: []
#
# object_id: 6
# raw label: gable-vent_round
# raw fields: ['gable-vent', 'round']
# new label: gable-vent
# attributes: {}
# attributes filed values: ['round']
#
# object_id: 7
# raw label: door
# raw fields: ['door']
# new label: door
# attributes: {}
# attributes filed values: []
#
# object_id: 8
# raw label: house-group
# raw fields: ['house-group']
# new label: house-group
# attributes: {}
# attributes filed values: []
#
# object_id: 9
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 10
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 11
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 12
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 13
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 14
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 15
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 16
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 17
# raw label: domer-window
# raw fields: ['domer-window']
# new label: domer-window
# attributes: {}
# attributes filed values: []
#
# object_id: 18
# raw label: domer-window
# raw fields: ['domer-window']
# new label: domer-window
# attributes: {}
# attributes filed values: []
#
# object_id: 19
# raw label: road
# raw fields: ['road']
# new label: road
# attributes: {}
# attributes filed values: []
#
# object_id: 20
# raw label: sidewalk
# raw fields: ['sidewalk']
# new label: sidewalk
# attributes: {}
# attributes filed values: []
#
# L:\Datasets\ocean_city\processed_json\114_W_Vo5VGnGn2IvT7PuajJrQ_230.14.json
# all_ids: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# isDuplicateID: True
# object_id: 1
# raw label: single-house
# raw fields: ['single-house']
# new label: single-house
# attributes: {}
# attributes filed values: []
#
# object_id: 2
# raw label: domer-window
# raw fields: ['domer-window']
# new label: domer-window
# attributes: {}
# attributes filed values: []
#
# object_id: 3
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 4
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# ...
# attributes: {}
# attributes filed values: []
#
# object_id: 7
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 8
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# object_id: 9
# raw label: decorative-shutter
# raw fields: ['decorative-shutter']
# new label: decorative-shutter
# attributes: {}
# attributes filed values: []
#
# object_id: 10
# raw label: window-round
# raw fields: ['window-round']
# new label: window-round
# attributes: {}
# attributes filed values: []
#
# object_id: 11
# raw label: bay-window
# raw fields: ['bay-window']
# new label: bay-window
# attributes: {}
# attributes filed values: []
#
# object_id: 12
# raw label: front-door
# raw fields: ['front-door']
# new label: front-door
# attributes: {}
# attributes filed values: []
#
# object_id: 13
# raw label: single-house_2
# raw fields: ['single-house', '2']
# Added attributes.storey_cnt:  2
# new label: single-house
# attributes: {'storey_cnt': '2'}
# attributes filed values: ['2']
#
# object_id: 14
# raw label: chimney
# raw fields: ['chimney']
# new label: chimney
# attributes: {}
# attributes filed values: []
#
# object_id: 15
# raw label: door
# raw fields: ['door']
# new label: door
# attributes: {}
# attributes filed values: []
#
# object_id: 16
# raw label: domer-window
# raw fields: ['domer-window']
# new label: domer-window
# attributes: {}
# attributes filed values: []
#
# object_id: 17
# raw label: single-house_2
# raw fields: ['single-house', '2']
# Added attributes.storey_cnt:  2
# new label: single-house
# attributes: {'storey_cnt': '2'}
# attributes filed values: ['2']
#
# object_id: 18
# raw label: chimney
# raw fields: ['chimney']
# new label: chimney
# attributes: {}
# attributes filed values: []
#
# object_id: 19
# raw label: deck
# raw fields: ['deck']
# new label: deck
# attributes: {}
# attributes filed values: []
#
# L:\Datasets\ocean_city\processed_json\93_z6qljoyo2laZF89kKVj52A_219.96.json
# all_ids: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# isDuplicateID: True
# object_id: 1
# raw label: single-house_2
# raw fields: ['single-house', '2']
# Added attributes.storey_cnt:  2
# new label: single-house
# attributes: {'storey_cnt': '2'}
# attributes filed values: ['2']
#
# object_id: 2
# raw label: door
# raw fields: ['door']
# new label: door
# attributes: {}
# attributes filed values: []
#
# object_id: 3
# raw label: step_2
# raw fields: ['step', '2']
# Added attributes.step_cnt:  2
# new label: step
# attributes: {'step_cnt': '2'}
# attributes filed values: ['2']
#
# object_id: 4
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 5
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 6
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 7
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 8
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 9
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 10
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 11
# raw label: porch
# raw fields: ['porch']
# new label: porch
# attributes: {}
# attributes filed values: []
#
# object_id: 12
# raw label: deck
# raw fields: ['deck']
# new label: deck
# attributes: {}
# attributes filed values: []
#
# object_id: 13
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 14
# raw label: single-house_2
# raw fields: ['single-house', '2']
# Added attributes.storey_cnt:  2
# new label: single-house
# attributes: {'storey_cnt': '2'}
# attributes filed values: ['2']
#
# object_id: 15
# raw label: house-group
# raw fields: ['house-group']
# new label: house-group
# attributes: {}
# attributes filed values: []
#
# L:\Datasets\ocean_city\processed_json\94_T0tbnT58Iydyw7qHCzO2Hg_176.92.json
# all_ids: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# isDuplicateID: True
# object_id: 1
# raw label: single-house_3
# raw fields: ['single-house', '3']
# Added attributes.storey_cnt:  3
# new label: single-house
# attributes: {'storey_cnt': '3'}
# attributes filed values: ['3']
#
# object_id: 2
# raw label: single-house_3
# raw fields: ['single-house', '3']
# Added attributes.storey_cnt:  3
# new label: single-house
# attributes: {'storey_cnt': '3'}
# attributes filed values: ['3']
#
# object_id: 3
# raw label: single-house_2
# raw fields: ['single-house', '2']
# Added attributes.storey_cnt:  2
# new label: single-house
# attributes: {'storey_cnt': '2'}
# attributes filed values: ['2']
#
# object_id: 4
# raw label: house-group
# raw fields: ['house-group']
# new label: house-group
# attributes: {}
# attributes filed values: []
#
# object_id: 5
# raw label: garage
# raw fields: ['garage']
# new label: garage
# attributes: {}
# attributes filed values: []
#
# object_id: 6
# raw label: garage
# raw fields: ['garage']
# new label: garage
# attributes: {}
# attributes filed values: []
#
# object_id: 7
# raw label: stair
# raw fields: ['stair']
# new label: stair
# attributes: {}
# attributes filed values: []
#
# object_id: 8
# raw label: deck
# raw fields: ['deck']
# new label: deck
# attributes: {}
# attributes filed values: []
#
# object_id: 9
# raw label: balcony
# raw fields: ['balcony']
# new label: balcony
# attributes: {}
# attributes filed values: []
#
# object_id: 10
# raw label: front-door
# raw fields: ['front-door']
# new label: front-door
# attributes: {}
# attributes filed values: []
#
# object_id: 11
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 12
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 13
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 14
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 15
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 16
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 17
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 18
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 19
# raw label: window-eyebow_extended_leg
# raw fields: ['window-eyebow', 'extended', 'leg']
# new label: window-eyebow
# attributes: {}
# attributes filed values: ['extended', 'leg']
#
# L:\Datasets\ocean_city\processed_json\95_rONwgumLQUY07pB5R6yUOA_233.5.json
# all_ids: [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# isDuplicateID: True
# object_id: 1
# raw label: bungalow
# raw fields: ['bungalow']
# new label: bungalow
# attributes: {}
# attributes filed values: []
#
# object_id: 2
# raw label: step_4
# raw fields: ['step', '4']
# Added attributes.step_cnt:  4
# new label: step
# attributes: {'step_cnt': '4'}
# attributes filed values: ['4']
#
# object_id: 3
# raw label: door
# raw fields: ['door']
# new label: door
# attributes: {}
# attributes filed values: []
#
# object_id: 4
# raw label: foundation
# raw fields: ['foundation']
# new label: foundation
# attributes: {}
# attributes filed values: []
#
# object_id: 5
# raw label: gable-window
# raw fields: ['gable-window']
# new label: gable-window
# attributes: {}
# attributes filed values: []
#
# object_id: 6
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 7
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 8
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 9
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 10
# raw label: terrace
# raw fields: ['terrace']
# new label: terrace
# attributes: {}
# attributes filed values: []
#
# object_id: 11
# raw label: single-house_3
# raw fields: ['single-house', '3']
# Added attributes.storey_cnt:  3
# new label: single-house
# attributes: {'storey_cnt': '3'}
# attributes filed values: ['3']
#
# object_id: 12
# raw label: garage
# raw fields: ['garage']
# new label: garage
# attributes: {}
# attributes filed values: []
#
# object_id: 13
# raw label: garage
# raw fields: ['garage']
# new label: garage
# attributes: {}
# attributes filed values: []
#
# object_id: 14
# raw label: deck
# raw fields: ['deck']
# new label: deck
# attributes: {}
# attributes filed values: []
#
# object_id: 15
# raw label: deck
# raw fields: ['deck']
# new label: deck
# attributes: {}
# attributes filed values: []
#
# object_id: 16
# raw label: stair
# raw fields: ['stair']
# new label: stair
# attributes: {}
# attributes filed values: []
#
# object_id: 17
# raw label: single-house_3
# raw fields: ['single-house', '3']
# Added attributes.storey_cnt:  3
# new label: single-house
# attributes: {'storey_cnt': '3'}
# attributes filed values: ['3']
#
# L:\Datasets\ocean_city\processed_json\96_1XFkv_-3Vqc91Bvz91uUvA_302.9.json
# all_ids: [None, None, None, None, None, None, None, None, None]
# isDuplicateID: True
# object_id: 1
# raw label: bungalow
# raw fields: ['bungalow']
# new label: bungalow
# attributes: {}
# attributes filed values: []
#
# object_id: 2
# raw label: step_9
# raw fields: ['step', '9']
# Added attributes.step_cnt:  9
# new label: step
# attributes: {'step_cnt': '9'}
# attributes filed values: ['9']
#
# object_id: 3
# raw label: foundation
# raw fields: ['foundation']
# new label: foundation
# attributes: {}
# attributes filed values: []
#
# object_id: 4
# raw label: door
# raw fields: ['door']
# new label: door
# attributes: {}
# attributes filed values: []
#
# object_id: 5
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 6
# raw label: porch
# raw fields: ['porch']
# new label: porch
# attributes: {}
# attributes filed values: []
#
# object_id: 7
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 8
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 9
# raw label: house-group
# raw fields: ['house-group']
# new label: house-group
# attributes: {}
# attributes filed values: []
#
# L:\Datasets\ocean_city\processed_json\97_iKNouL65svY3oqxVHRyY7Q_334.54.json
# all_ids: [None, None, None, None, None, None, None, None, None, None, None]
# isDuplicateID: True
# object_id: 1
# raw label: single-house_2
# raw fields: ['single-house', '2']
# Added attributes.storey_cnt:  2
# new label: single-house
# attributes: {'storey_cnt': '2'}
# attributes filed values: ['2']
#
# object_id: 2
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 3
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 4
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 5
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 6
# raw label: gable-window
# raw fields: ['gable-window']
# new label: gable-window
# attributes: {}
# attributes filed values: []
#
# object_id: 7
# raw label: domer-window
# raw fields: ['domer-window']
# new label: domer-window
# attributes: {}
# attributes filed values: []
#
# object_id: 8
# raw label: balcony
# raw fields: ['balcony']
# new label: balcony
# attributes: {}
# attributes filed values: []
#
# object_id: 9
# raw label: single-house_2
# raw fields: ['single-house', '2']
# Added attributes.storey_cnt:  2
# new label: single-house
# attributes: {'storey_cnt': '2'}
# attributes filed values: ['2']
#
# object_id: 10
# raw label: step_>5
# raw fields: ['step', '>5']
# new label: step
# attributes: {}
# attributes filed values: ['>5']
#
# object_id: 11
# raw label: house
# raw fields: ['house']
# new label: house
# attributes: {}
# attributes filed values: []
#
# L:\Datasets\ocean_city\processed_json\98_WHmViscF_6leDhpZLosXSQ_326.26.json
# all_ids: [None, None, None, None, None, None, None, None, None, None]
# isDuplicateID: True
# object_id: 1
# raw label: ranch
# raw fields: ['ranch']
# new label: ranch
# attributes: {}
# attributes filed values: []
#
# object_id: 2
# raw label: front-door
# raw fields: ['front-door']
# new label: front-door
# attributes: {}
# attributes filed values: []
#
# object_id: 3
# raw label: step_3
# raw fields: ['step', '3']
# Added attributes.step_cnt:  3
# new label: step
# attributes: {'step_cnt': '3'}
# attributes filed values: ['3']
#
# object_id: 4
# raw label: foundation
# raw fields: ['foundation']
# new label: foundation
# attributes: {}
# attributes filed values: []
#
# object_id: 5
# raw label: garage
# raw fields: ['garage']
# new label: garage
# attributes: {}
# attributes filed values: []
#
# object_id: 6
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 7
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 8
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 9
# raw label: ranch
# raw fields: ['ranch']
# new label: ranch
# attributes: {}
# attributes filed values: []
#
# object_id: 10
# raw label: ranch
# raw fields: ['ranch']
# new label: ranch
# attributes: {}
# attributes filed values: []
#
# L:\Datasets\ocean_city\processed_json\99_knxYmIUR3lddp9sbVp1x2w_218.7.json
# all_ids: [None, None, None, None, None, None, None, None, None, None, None, None]
# isDuplicateID: True
# object_id: 1
# raw label: single-house_2
# raw fields: ['single-house', '2']
# Added attributes.storey_cnt:  2
# new label: single-house
# attributes: {'storey_cnt': '2'}
# attributes filed values: ['2']
#
# object_id: 2
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 3
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 4
# raw label: gable-window_diamond
# raw fields: ['gable-window', 'diamond']
# new label: gable-window
# attributes: {}
# attributes filed values: ['diamond']
#
# object_id: 5
# raw label: domer-window
# raw fields: ['domer-window']
# new label: domer-window
# attributes: {}
# attributes filed values: []
#
# object_id: 6
# raw label: domer-window
# raw fields: ['domer-window']
# new label: domer-window
# attributes: {}
# attributes filed values: []
#
# object_id: 7
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 8
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 9
# raw label: window
# raw fields: ['window']
# new label: window
# attributes: {}
# attributes filed values: []
#
# object_id: 10
# raw label: front-door
# raw fields: ['front-door']
# new label: front-door
# attributes: {}
# attributes filed values: []
#
# object_id: 11
# raw label: step_4
# raw fields: ['step', '4']
# Added attributes.step_cnt:  4
# new label: step
# attributes: {'step_cnt': '4'}
# attributes filed values: ['4']
#
# object_id: 12
# raw label: step_1
# raw fields: ['step', '1']
# Added attributes.step_cnt:  1
# new label: step
# attributes: {'step_cnt': '1'}
# attributes filed values: ['1']
#
# L:\Datasets\ocean_city\processed_json\9_as2lf1LPPhGI1D5DEQtDyA_55.07.json
# all_ids: [None, None, None]
# isDuplicateID: True
# object_id: 1
# raw label: single-house_2
# raw fields: ['single-house', '2']
# Added attributes.storey_cnt:  2
# new label: single-house
# attributes: {'storey_cnt': '2'}
# attributes filed values: ['2']
#
# object_id: 2
# raw label: step_3
# raw fields: ['step', '3']
# Added attributes.step_cnt:  3
# new label: step
# attributes: {'step_cnt': '3'}
# attributes filed values: ['3']
#
# object_id: 3
# raw label: single-house_1
# raw fields: ['single-house', '1']
# Added attributes.storey_cnt:  1
# new label: single-house
# attributes: {'storey_cnt': '1'}
# attributes filed values: ['1']
